# %% [markdown]
# # 第二部份,加入內容進去

# %%
# for content in hrefs:
#     res = requests.get(content[0])
#     soup = BeautifulSoup(res.text, 'lxml') 
#     job_content = soup.select('div.JobDescription')[0].text #job_content
#     job_require = soup.select('div.job-detail-box > dl')[0].text #job_require
#     c = (job_content + job_require)
#     d = c.replace('\n',' ').encode('ascii', 'ignore')
#     print(d.decode())
#     把工作內容和職缺需求取出,並用ascii字元取代

# %%
def job518_for_info(href): #解析出內文並回存進資料庫
    
    import requests
    from bs4 import BeautifulSoup
    import time
    time.sleep(1)
    try:
        res = requests.get(href)
            #if requests.status_code !=200: #如果網頁異常拋出例外
                #raise CrawlerError('CrawlerError','requests is error!') 

        soup = BeautifulSoup(res.text,'lxml')
        job_content = soup.select('div.JobDescription')[0].text #job_content
        job_require = soup.select('div.job-detail-box > dl')[0].text #job_require
        d = (job_content + job_require)
        new_info = d.replace('\n',' ').encode('ascii','ignore')
        new_info = new_info.decode('utf8')


        with sqlite3.connect('job.sqlite') as conn:
            c = conn.cursor()  #p-10-12 ,3-17
            save_info = "update job518 set info = ? where href = ?" 
            c.execute(save_info,(new_info,href))
    except IndexError as e:
        print(e, href)
    
class CrawlerError(Exception): #爬蟲例外 例外方法寫在def裏面
    pass

# %%
def update_None_info(): #存進資料庫
    
    import requests
    import sqlite3
    from bs4 import BeautifulSoup
    
    try:
        with sqlite3.connect('job.sqlite') as conn:

            c = conn.cursor()
            qryString = "SELECT href FROM job518 where info is Null" #找出info是空的url並out出網址list
            c.execute(qryString)
            
            do_number = 0 #計算有多少筆完成
            
            lst = c.fetchall()
            
            for a in lst:
                # http://case.518.com.tw/casepage-detail-124929.html?from=518&a_id=2183
                if a[0][0:15] != 'http://case.518': #若開頭網址不是case類型的,才進入迴圈
                    job518_for_info(a[0]) 
                    do_number +=1
                    if do_number % 10 == 0:
                        print(do_number)
                else:
                    print("外包網頁") #若出現則顯示外包網頁
                
            print('Has crawled {} info!'.format(do_number))
            
    except ConnectionError as e:
        print(e)
        print(a)
        print(href)
        
    except CrawlerError as e:
        print(a)
        print(e)

# %%
update_None_info()#執行方法
# Out:
# 10
# 20
# 外包網頁
# 外包網頁
# 外包網頁
# 30
# list index out of range https://www.518.com.tw/西區(代徵)PHP程式工程師-台中市-西區-job-1298430.html?kw=&pi=2
# 40
# 外包網頁
# 外包網頁
# 外包網頁
# 50
# 60
# 外包網頁
# 外包網頁
# 外包網頁
# 70
# 80
# 外包網頁
# 外包網頁
# 外包網頁
# 90
# 100
# 外包網頁
# 外包網頁
# 外包網頁
# 110
# 120
# 外包網頁
# 外包網頁
# 外包網頁
# 130
# 140
# 外包網頁
# 外包網頁
# 外包網頁
# 150
# 160
# 外包網頁
# 外包網頁
# 外包網頁
# 170
# 180
# 外包網頁
# 外包網頁
# 外包網頁
# 190
# 200
# 外包網頁
# 外包網頁
# 外包網頁
# 210
# 220
# 外包網頁
# 外包網頁
# 外包網頁
# 230
# 240
# 外包網頁
# 外包網頁
# 外包網頁
# 250
# 260
# 外包網頁
# 外包網頁
# 外包網頁
# 270
# 280
# 外包網頁
# 外包網頁
# 外包網頁
# 290
# 300
# 外包網頁
# 外包網頁
# 外包網頁
# 310
# 320
# 外包網頁
# 外包網頁
# 外包網頁
# 330
# 340
# 外包網頁
# 外包網頁
# 外包網頁
# 350
# 360
# 外包網頁
# 外包網頁
# 外包網頁
# 370
# 380
# 外包網頁
# 外包網頁
# 外包網頁
# 390
# 400
# 外包網頁
# 外包網頁
# 外包網頁
# 410
# 420
# 外包網頁
# 外包網頁
# 外包網頁
# 430
# 440
# 外包網頁
# 外包網頁
# 外包網頁
# 450
# 460
# 外包網頁
# 外包網頁
# 外包網頁
# 470
# 480
# 外包網頁
# 外包網頁
# 外包網頁
# 490
# 500
# 外包網頁
# 外包網頁
# 外包網頁
# 510
# 520
# 外包網頁
# 外包網頁
# 外包網頁
# 530
# 540
# 外包網頁
# 外包網頁
# 外包網頁
# 550
# 560
# 外包網頁
# 外包網頁
# 外包網頁
# 570
# 580
# 外包網頁
# 外包網頁
# 外包網頁
# 590
# 600
# 外包網頁
# 外包網頁
# 外包網頁
# 610
# 620
# 外包網頁
# 外包網頁
# 外包網頁
# 630
# 640
# 外包網頁
# 外包網頁
# 外包網頁
# 650
# 660
# 外包網頁
# 外包網頁
# 外包網頁
# 670
# 680
# 外包網頁
# 外包網頁
# 外包網頁
# 690
# 700
# 外包網頁
# 外包網頁
# 外包網頁
# 710
# 720
# 外包網頁
# 外包網頁
# 外包網頁
# 730
# 740
# 外包網頁
# 外包網頁
# 外包網頁
# 750
# 760
# 外包網頁
# 外包網頁
# 外包網頁
# 770
# 780
# 外包網頁
# 外包網頁
# 外包網頁
# 790
# 800
# 外包網頁
# 外包網頁
# 外包網頁
# 810
# 820
# 外包網頁
# 外包網頁
# 外包網頁
# 830
# 840
# 外包網頁
# 外包網頁
# 外包網頁
# 850
# 860
# 外包網頁
# 外包網頁
# 外包網頁
# 870
# 880
# 外包網頁
# 外包網頁
# 外包網頁
# 890
# 900
# 外包網頁
# 外包網頁
# 外包網頁
# 910
# 920
# 外包網頁
# 外包網頁
# 外包網頁
# 930
# 940
# 外包網頁
# 外包網頁
# 外包網頁
# 950
# 960
# 外包網頁
# 外包網頁
# 外包網頁
# 970
# 980
# 外包網頁
# 外包網頁
# 外包網頁
# 990
# 1000
# 外包網頁
# 外包網頁
# 外包網頁
# 1010
# 1020
# 1030
# 1040
# 1050
# 1060
# Has crawled 1067 info!

# %%
with sqlite3.connect('job.sqlite') as conn: #存進資料庫
    c = conn.cursor()
    pprint.pprint(list(c.execute('select * from job518')))
# Out:
# [(1,
#   'Android程式設計師',
#   'https://www.518.com.tw/Android程式設計師-新北市-三重區-job-886709.html?kw=&pi=1',
#   1,
#   ' \r'
#   ' AndroidIOSline3Dapp080sipIVRapp  :1. Java, C++ 2. iOSAndroid 3DApp3. 3D4.  '
#   'Unity 5. Socket Programming, TCP/IP        /      2          :1. Java, C++ '
#   '2. iOSAndroid 3DApp3. 3D4.  Unity 5. Socket Programming, TCP/IP   2 '),
#  (2,
#   'Internet程式設計師、PHP網站程式設計師',
#   'https://www.518.com.tw/Internet程式設計師、PHP網站程式設計師-新北市-三重區-job-949808.html?kw=&pi=1',
#   1,
#   ' \r'
#   '        /          :/:/:/:  C/C++Visual C++WordOutlookExcel    1. 2.   1 '),
#  (3,
#   '101_網站工程師',
#   'https://www.518.com.tw/101_網站工程師-新北市-三重區-job-660380.html?kw=&pi=1',
#   1,
#   ' \r'
#   ' 2017.6121()  1. PHPJSMYSQL 2.  / (FBYahoo...) /  /  3. / 4.  5.     2 '
#   '16        /      1      MySQLPHPJava ScriptJavaAJAX    !  1 '),
#  (4,
#   'BIM研發經理',
#   'https://www.518.com.tw/BIM研發經理-台北市-信義區-job-1356565.html?kw=&pi=1',
#   1,
#   ' \r 1.BIMBIM 2.WEB 3.iOS/Android App       /  4    5            1 '),
#  (5,
#   '軟體研發工程師',
#   'https://www.518.com.tw/軟體研發工程師-台北市-信義區-job-1356524.html?kw=&pi=1',
#   1,
#   ' \r BIM WEB,App HTML/CSS/JS MongoDB/MSSQL/.NET       /                   '),
#  (6,
#   'IT網管工程師',
#   'https://www.518.com.tw/IT網管工程師-台中市-西區-job-1348801.html?kw=&pi=1',
#   1,
#   ' \r'
#   ' 1 2IT 3 4 5         /          :/:/:/:  LinuxWindows Server 2008Windows '
#   'Server 2012MySQLVmware  (Security test)(Bug tracking)  1FirewallIPS 2 3 4 5 '
#   '6 7  (/) 1(F5CISCOJUNIPERFortinet) 2200 3 IT 4 5   '),
#  (7,
#   '電腦工程師',
#   'https://www.518.com.tw/電腦工程師-新北市-樹林區-job-829908.html?kw=&pi=1',
#   1,
#   ' \r'
#   '  ,  , TCP/IP   ,         /            PowerPointWindows XPWindows 7  '
#   '(function test)(Usability test)(Bug tracking)    1-2 '),
#  (8,
#   '網頁美工印刷電腦設計師',
#   'https://www.518.com.tw/網頁美工印刷電腦設計師-桃園市-龍潭區-job-1163675.html?kw=&pi=1',
#   1,
#   ' \r'
#   ' 1.  2.  3.         /  5-8    2    :/:/:/: : DHTMLFlashFrontPageHTMLCSSWeb '
#   'Master/DeveloperActiveXJavaScriptDreamweaver       '),
#  (9,
#   '系統分析專案主管(台北)',
#   'https://www.518.com.tw/系統分析專案主管(台北)-台北市-中正區-job-1255792.html?kw=&pi=1',
#   1,
#   ' \r'
#   ' 1. Internet \r'
#   ' 2. C#  .NET Framework \r'
#   ' 3. SQL \r'
#   ' 4.       /  4    2      C#.NET    :2  1 '),
#  (10,
#   '程式設計師(台北)',
#   'https://www.518.com.tw/程式設計師(台北)-台北市-中正區-job-863111.html?kw=&pi=1',
#   1,
#   ' \r'
#   ' :  1. Internet  2. C#  .NET Framework  3. SQL  4. 5.       /            '
#   'C#.NET      1-2 '),
#  (11,
#   '徵美工助理兼網拍內勤人員',
#   'https://www.518.com.tw/徵美工助理兼網拍內勤人員-台中市-大里區-job-208730.html?kw=&pi=1',
#   1,
#   ' \r'
#   ' 1. 2.EXCEL ,  3. 4. ...  5.PHOTOSHOP(,.. ) ................PS.  ,  ,  '
#   '!...........       /          :/:/:/::/:/:/: : Windows '
#   'XPWordExcelPowerPointAdobe Photoshop50~75POS      2 '),
#  (12,
#   '電腦維修工程師',
#   'https://www.518.com.tw/電腦維修工程師-桃園市-桃園區-job-1009036.html?kw=&pi=1',
#   1,
#   ' \r 1. 2. 3.       /                  1 '),
#  (13,
#   '相機網拍行政人員',
#   'https://www.518.com.tw/相機網拍行政人員-新竹縣-竹北市-job-1274757.html?kw=&pi=1',
#   1,
#   ' \r 3C           /          :/:/:/::/:/:/: : WordExcelMac OS      1-2 '),
#  (14,
#   '其它資訊專業人員',
#   'https://www.518.com.tw/其它資訊專業人員-高雄市-鳳山區-job-1230061.html?kw=&pi=1',
#   1,
#   ' \r'
#   ' 1. 2. 3.ExcelOutlookPowerPointWord50~7520~50        /            '
#   'WordPowerPointExcelOutlookInternet Explorer50~7520~50       '),
#  (15,
#   '電子商務技術人員',
#   'https://www.518.com.tw/電子商務技術人員-高雄市-鳳山區-job-1230065.html?kw=&pi=1',
#   1,
#   ' \r 1. 2. 3.        /                   '),
#  (16,
#   'C# .NET 軟體工程師',
#   'https://www.518.com.tw/C.NET軟體工程師-新北市-新莊區-job-1210201.html?kw=&pi=1',
#   1,
#   ' \r'
#   '  C#       Required Skills  Experience  *  Object Oriented Design ,Design '
#   'Pattern.  *  .NET C#  *  (MS-SQL)  * Extremely collaborative and '
#   'self-motivated   Nice To Have Skills  Experience  *  * Unit test  * CI/CD  '
#   'DevOps  Jenkins             * Cirple   * Stranity      *  *  *     '
#   '1.2.3....  :  1.  2.  3.  () 4.  5.  6.  7.  8.        /      2    '
#   ':/:/:/:        1-2 '),
#  (17,
#   'Internet程式設計-早班',
#   'https://www.518.com.tw/Internet程式設計-早班-嘉義市-東區-job-1245885.html?kw=&pi=1',
#   1,
#   ' \r'
#   ' 518 ----- :    PHP ----- 40000 () : 10:00 - 18:30 -----  1.(4~5) 2.3~4 3. '
#   '4. 5. 6.67       /                   '),
#  (18,
#   'V-近頂埔捷運((可週領))[品檢][測試][機台操作]時薪186-266',
#   'https://www.518.com.tw/V-近頂埔捷運((可週領))[品檢][測試][機台操作]時薪186-266-新北市-板橋區-job-1338811.html?kw=&pi=1',
#   1,
#   ' \r'
#   ' 3/()   Ella <<<186~266>>>      0900-058942  LINE0900058942 ()    '
#   '*,.*______ELLA_________*,.*    6%  (: :5-10)  *,.*____________*,.* () ()  '
#   '{{ }}  08:00~16:30  16:00~24:30    24:00~08:30    :25390~$38000 () '
#   ':32000~$41000 () :36000~$45000 ()   50356  () 53876  ()    52 (8)   -()  '
#   '6     :(( )) 0900-058942(LINEID:0900058942) 0978-969880(LINEID:hsi817) '
#   '0978-268290(LINEID:a0978268290)   :0900-058942  LINEID:0900058942         '
#   '/                   '),
#  (19,
#   '資訊助理人員 (實習生亦可)',
#   'https://www.518.com.tw/資訊助理人員(實習生亦可)-新北市-林口區-job-1223414.html?kw=&pi=1',
#   1,
#   ' \r 1. 2. 3. 4. 5.        /                  1 '),
#  (20,
#   '軟體業務客服工程師(高雄)',
#   'https://www.518.com.tw/軟體業務客服工程師(高雄)-高雄市-全區-job-168750.html?kw=&pi=1',
#   1,
#   ' \r        /,1                   '),
#  (21,
#   '網路美工助理',
#   'https://www.518.com.tw/網路美工助理-台南市-東區-job-1200435.html?kw=&pi=1',
#   1,
#   ' \r'
#   ' 1.  2. 3.EXCEL ,  4. 5. ...  6.PHOTOSHOP(,.. ) ................PS.  ,  '
#   '!...........       /      2      POSWindows '
#   '8WordPowerPointExcelIllustratorAdobe Photoshop      1-2 '),
#  (22,
#   'Google Android 手機App 開發人員',
#   'https://www.518.com.tw/GoogleAndroid手機App開發人員-台北市-大同區-job-865557.html?kw=&pi=1',
#   1,
#   ' \r'
#   ' 1. Java  2. Android App .  :1. Java, C++ 2. iOSAndroid 3DApp3. 3D4.  Unity '
#   '5. Socket Programming, TCP/IP        /      2          1. Java, C++  2. '
#   'iOSAndroid 3DApp 3. 3D 4.  Unity  5. Socket Programming, TCP/IP   2 '),
#  (23,
#   'Android APP應用程式開發人員',
#   'https://www.518.com.tw/AndroidAPP應用程式開發人員-台北市-大同區-job-863999.html?kw=&pi=1',
#   1,
#   ' \r'
#   ' AndroidIOSline3Dapp080sipIVRapp  :1. Java, C++ 2. iOSAndroid 3DApp3. 3D4.  '
#   'Unity 5. Socket Programming, TCP/IP        /      2          :1. Java, C++ '
#   '2. iOSAndroid 3DApp3. 3D4.  Unity 5. Socket Programming, TCP/IP   2 '),
#  (24,
#   '架設會員管理網站',
#   'http://case.518.com.tw/casepage-detail-124929.html?from=518&a_id=2183',
#   1,
#   None),
#  (25,
#   'ASP.NET(VB) 程式設計修改',
#   'http://case.518.com.tw/casepage-detail-124932.html?from=518&a_id=2183',
#   1,
#   None),
#  (26,
#   '拼接圖形開發',
#   'http://case.518.com.tw/casepage-detail-124914.html?from=518&a_id=2183',
#   1,
#   None),
#  (27,
#   '軟體設計工程師',
#   'https://www.518.com.tw/軟體設計工程師-新北市-板橋區-job-1354552.html?kw=&pi=2',
#   1,
#   ' \r            ,6            C#ASP.NETJava ScriptMS SQLIIS    MVC  1-2 '),
#  (28,
#   '系統企劃專員(台北 南港)',
#   'https://www.518.com.tw/系統企劃專員(台北南港)-台北市-南港區-job-764752.html?kw=&pi=2',
#   1,
#   ' \r'
#   ' 1.\r'
#   ' 2.       /      2      WordPowerPointOutlookExcelInternet ExplorerMS '
#   'SQLWindows 2003Windows 2000Windows XP    1. ()2. 3. 4.  1 '),
#  (29,
#   '.NET 軟體專案開發主管',
#   'https://www.518.com.tw/.NET軟體專案開發主管-台北市-松山區-job-1033422.html?kw=&pi=2',
#   1,
#   ' \r'
#   ' 1. ASP.NET  MVC 2. C#web  3. ORCALEMS-SQL 4. N-TierOOPTeam Foundation  5. '
#   'UML   6. Object-relational mappingLINQADO.NET Entity Framework  7.  8.  9.  '
#   '10.  11. Microsoft        /  4    3    :/:/:/:        2 '),
#  (30,
#   'Drupal 網站開發助理工程師(後端)',
#   'https://www.518.com.tw/Drupal網站開發助理工程師(後端)-台北市-大安區-job-1174327.html?kw=&pi=2',
#   1,
#   ' \r'
#   ' 1.  Drupal  2.  Drupal  3.  Drupal        /            '
#   'PHPHTMLJavaScriptCSS     Drupal CMS  Drupal    '),
#  (31,
#   '專案經理',
#   'https://www.518.com.tw/專案經理-台北市-松山區-job-1117021.html?kw=&pi=2',
#   1,
#   ' \r 1.  2.  3.  4.  5.        /                   '),
#  (32,
#   '軟體工程師',
#   'https://www.518.com.tw/軟體工程師-台北市-松山區-job-963920.html?kw=&pi=2',
#   1,
#   ' \r'
#   ' 1. (SmartBPM.NET ) 2. ( C# ExtJs) 3.  4.  4.  ASP.NET MVC        '
#   '/          :/:/:/: :       1-2 '),
#  (33,
#   '軟體客服專員',
#   'https://www.518.com.tw/軟體客服專員-台北市-松山區-job-963922.html?kw=&pi=2',
#   1,
#   ' \r 1.  2.  3.                           '),
#  (34,
#   '軟體工程師(台中)',
#   'https://www.518.com.tw/軟體工程師(台中)-台中市-南屯區-job-965774.html?kw=&pi=2',
#   1,
#   ' \r'
#   '       //PM      /PM          /      (C#)     1. (SmartBPM.NET )     2. ( '
#   'C# ExtJs)     3.  ASP.NET MVCAngularJSSignalR     4.       /PM     1. '
#   '(SmartBPM.NET  )     2.  /     3.        /                   '),
#  (35,
#   '.NET 技術主管(台中)',
#   'https://www.518.com.tw/.NET技術主管(台中)-台中市-南屯區-job-1355023.html?kw=&pi=2',
#   1,
#   ' \r'
#   ' 1. ASP.NET  MVC 2. C#web  3. ORCALEMS-SQL 4. N-TierOOPTeam Foundation  5. '
#   'UML   6. Object-relational mappingLINQADO.NET Entity Framework  7.  8.  9.  '
#   '10.  11. Microsoft        /  4    3    :/:/:/:        2 '),
#  (36,
#   '.NET 軟體工程師(台中)',
#   'https://www.518.com.tw/.NET軟體工程師(台中)-台中市-南屯區-job-1355024.html?kw=&pi=2',
#   1,
#   ' \r'
#   ' 1. (SmartBPM.NET ) 2. ( C# ExtJs) 3.  4.  4.  ASP.NET MVC        '
#   '/          :/:/:/: :       1-2 '),
#  (37,
#   '電腦操作人員',
#   'https://www.518.com.tw/電腦操作人員-新北市-新莊區-job-1242619.html?kw=&pi=2',
#   1,
#   ' \r 1. 2. 3.Line 4. 5.        /                  1 '),
#  (38,
#   '遊戲軟體程式設計師',
#   'https://www.518.com.tw/遊戲軟體程式設計師-高雄市-全區-job-746885.html?kw=&pi=2',
#   1,
#   ' \r 1.   2.         /            Visual C++C/C++WIN CELinux       '),
#  (39,
#   '資訊人員',
#   'https://www.518.com.tw/資訊人員-新北市-林口區-job-1305795.html?kw=&pi=2',
#   1,
#   ' \r 1. 2.//  3. 4.//  5. 6. 7.       /      2             '),
#  (40,
#   '資訊安全工程師',
#   'https://www.518.com.tw/資訊安全工程師-新北市-新店區-job-867482.html?kw=&pi=2',
#   1,
#   ' \r'
#   ' ()                   :/:/:/::/:/:/:      CJavaPython [] (Full Stack)    '),
#  (41,
#   '系統研發工程師',
#   'https://www.518.com.tw/系統研發工程師-台北市-大同區-job-1223215.html?kw=&pi=2',
#   1,
#   ' \r'
#   ' 1. 2. 3. 4. 5.       /            '
#   'Mac/MacintoshHTTPJavaScriptHTMLjQueryPHPLinux  (function test)(Security '
#   'test)(Usability test)  1. 1()  2.  PHP PHP  3.  Linux / MySQL / MongoDB   '
#   '4.  Git   5.  HTML / CSS / JavaScript   6. Open Source  2-3 '),
#  (42,
#   '西區 (代徵)PHP程式工程師',
#   'https://www.518.com.tw/西區(代徵)PHP程式工程師-台中市-西區-job-1298430.html?kw=&pi=2',
#   1,
#   None),
#  (43,
#   '網站/網頁前端工程師',
#   'https://www.518.com.tw/網站網頁前端工程師-台北市-中山區-job-1125252.html?kw=&pi=2',
#   1,
#   ' \r'
#   '        1.  2.  HTML / CSS / JQuery / Bootstrap       /                 1.  '
#   '2.  HTML / CSS / JQuery / Bootstrap   '),
#  (44,
#   'Android 工程師',
#   'https://www.518.com.tw/Android工程師-台北市-中山區-job-1125246.html?kw=&pi=2',
#   1,
#   ' \r'
#   ' Android  API   1.  2.  Android App  3.  Android Studio  --  '
#   'bei@jackercleaning.com       /                 1.  2.  Android App  3.  '
#   'Android Studio   1-2 '),
#  (45,
#   '前端工程師',
#   'https://www.518.com.tw/前端工程師-台北市-中山區-job-1166575.html?kw=&pi=2',
#   1,
#   ' \r'
#   ' 1 2 3 4 5coding style 6jQueryCSSHTMLJavaScriptBootstrap       /      3    '
#   ':/:/:/:  HTMLJavaScriptjQueryAdobe Photoshop    2  - CSS3, HTML5 '
#   '(Responsive CSS ). - Javascript/AJAX (jQuery )  - . - (, ) - . - .   '),
#  (46,
#   'PHP程式設計師',
#   'https://www.518.com.tw/PHP程式設計師-台北市-中山區-job-1166542.html?kw=&pi=2',
#   1,
#   ' \r'
#   ' 1. 2. 3. 4. 5.       /      3    :/:/:/:  AJAXPHPMySQLJavaScriptjQuery    '
#   '1.PHPJava 2. 3. 4. 5.   '),
#  (47,
#   '數據機率分析模型',
#   'http://case.518.com.tw/casepage-detail-124913.html?from=518&a_id=2183',
#   1,
#   None),
#  (48,
#   '健康檢查預約-網頁設計+切版+程式開發',
#   'http://case.518.com.tw/casepage-detail-124906.html?from=518&a_id=2183',
#   1,
#   None),
#  (49,
#   '前端網站UI/UX,Jquery客製動畫',
#   'http://case.518.com.tw/casepage-detail-124896.html?from=518&a_id=2183',
#   1,
#   None),
#  (50,
#   'MIS工程師/專員',
#   'https://www.518.com.tw/MIS工程師專員-新北市-汐止區-job-1333868.html?kw=&pi=3',
#   1,
#   ' \r'
#   '  1.  2.  3.  4.        /          :/:/:/:  Windows 7Windows Server '
#   '2012AndroidPCPCEthernetFTPHTTPIISTCP/IP      1 '),
#  (51,
#   '會計(具網拍經驗網站行銷企劃後台管理者)可兼',
#   'https://www.518.com.tw/會計(具網拍經驗網站行銷企劃後台管理者)可兼-高雄市-鼓山區-job-952113.html?kw=&pi=3',
#   1,
#   ' \r ..          /      2          ..     '),
#  (52,
#   'iOS 軟體工程師',
#   'https://www.518.com.tw/iOS軟體工程師-台北市-中山區-job-1166547.html?kw=&pi=3',
#   1,
#   ' \r'
#   ' iOS(iPhone/iPad) App App: 1.App: CameraNFCBluetooth 2.App 3.App 4.App: '
#   'App       /      3    :/:/:/:  CC++Objective-C    1.Objective-CC/C++ 2.iOS '
#   '3. 4. 5.   '),
#  (53,
#   '軟體程式設計工程師助理',
#   'https://www.518.com.tw/軟體程式設計工程師助理-高雄市-三民區-job-1331008.html?kw=&pi=3',
#   1,
#   ' \r'
#   ' 1 2 3             1      LinuxASPC/C++JavaJSPVisual BasicVisual '
#   'C++DbaseAccessMS SQLDHTMLJavaScriptVBScriptAdobe PhotoshopCoolDrawCorel '
#   'DrawIllustratorPhotoImpactAssembly       '),
#  (54,
#   'IT 維護工程師',
#   'https://www.518.com.tw/IT維護工程師-高雄市-三民區-job-1349393.html?kw=&pi=3',
#   1,
#   ' \r 1. 2. 3. 4. 5. 6.()       /      1             '),
#  (55,
#   '機電工程師',
#   'https://www.518.com.tw/機電工程師-新北市-樹林區-job-1355556.html?kw=&pi=3',
#   1,
#   ' \r 1.  2. .. 3.      OPCHMI..       ,1                  2-3 '),
#  (56,
#   'ASP NET軟體工程師',
#   'https://www.518.com.tw/ASPNET軟體工程師-台北市-大安區-job-1066269.html?kw=&pi=3',
#   1,
#   ' \r'
#   ' 1. MS SQL  2. ASP.net for C# or VB ,jQuery       /            HTMLMS '
#   'SQLASPASP.NETC#.NETVisual Basic .netVisual BasicJava Script       '),
#  (57,
#   'ASP.NET MVC 程式設計師',
#   'https://www.518.com.tw/ASP.NETMVC程式設計師-桃園市-大溪區-job-1340350.html?kw=&pi=3',
#   1,
#   ' \r'
#   ' 1.(ASP.Net C# MVC)MSSQL  2. 3. 4. 5.       /            ASP.NET      1 '),
#  (58,
#   '日本 大手運動用品公司 -IT部門主管-',
#   'https://www.518.com.tw/日本大手運動用品公司-IT部門主管--台中市-全區-job-1346690.html?kw=&pi=3',
#   1,
#   ' \r'
#   '  IT ()   IT      / 8 117               '
#   '---------------------------------------------------------------- ()       '
#   'CareerSun               /          :/:/:/:      /   1-5 '),
#  (59,
#   '日本 大手運動用品公司 -IT部門主管-',
#   'https://www.518.com.tw/日本大手運動用品公司-IT部門主管--其它亞洲-東北亞-job-1346687.html?kw=&pi=3',
#   1,
#   ' \r'
#   '  IT ()   IT      / 8 117               '
#   '---------------------------------------------------------------- ()       '
#   'CareerSun               /          :/:/:/:      /   1-5 '),
#  (60,
#   '(資深) PHP工程師',
#   'https://www.518.com.tw/(資深)PHP工程師-台北市-中山區-job-974471.html?kw=&pi=3',
#   1,
#   ' \r'
#   ' 1PHP,Java Script\r'
#   ' 2Codeigniter\r'
#   ' 3EX:SMS\r'
#   ' 4Linux+Apache+MySQL+PHP(LAMP)       /      2             '),
#  (61,
#   '業務助理',
#   'https://www.518.com.tw/業務助理-高雄市-苓雅區-job-990093.html?kw=&pi=3',
#   1,
#   ' \r'
#   ' 1. !\r'
#   ' 2. !\r'
#   ' 3. ,,!\r'
#   ' 4. ,!\r'
#   ' 5. !             1    :/:/:/::/:/:/:  WordExcelOutlookAdobe '
#   'AcrobatPowerPointAutoCADCorel DrawWindows 7Windows XP50~75      1 '),
#  (62,
#   '777-(北區免輪班8小時)周周休2日/高轉正,際',
#   'https://www.518.com.tw/777-(北區免輪班8小時)周周休2日高轉正,際-新北市-全區-job-1337757.html?kw=&pi=3',
#   1,
#   ' \r'
#   ' # https://www.facebook.com/goodbadjob/     PCB      ()  0966-679880 (ID)   '
#   ':+=  :      07:50-17:10   19:50-05:10     25520-34000   33220-47000      '
#   '+6%          LineID0966679880 (24)  : 0966-679-880   :++=         '
#   '/                   '),
#  (63,
#   '777-(湖口)全新宿舍/月休10天/免輪班,際',
#   'https://www.518.com.tw/777-(湖口)全新宿舍月休10天免輪班,際-新竹縣-新豐鄉-job-1337709.html?kw=&pi=3',
#   1,
#   ' \r'
#   ' # https://www.facebook.com/goodbadjob/     PCB     +  0966-679880 (ID)   '
#   ':+=  :      08:00-20:30   20:20-08:10     31000  39000     +6%            '
#   'LineID0966679880 (24)  : 0966-679-880   :++=        /                   '),
#  (64,
#   '2017演員培訓計畫(D)',
#   'https://www.518.com.tw/2017演員培訓計畫(D)-台北市-信義區-job-1351601.html?kw=&pi=3',
#   1,
#   ' \r'
#   '  ---()                 !   ________________________________________  '
#   'https://www.facebook.com/exmark    -  '
#   'https://www.facebook.com/media/set/?set=a.870183346392604.1073741863.636153906462217type=3   '
#   '-  '
#   'https://www.facebook.com/exmark/photos/?tab=albumalbum_id=852465881497684  '
#   '- '
#   'https://www.facebook.com/exmark/photos/?tab=albumalbum_id=789368981140708   '
#   '-  '
#   'https://www.facebook.com/exmark/photos/?tab=albumalbum_id=896811270396478   '
#   '-  '
#   'https://www.facebook.com/exmark/photos/?tab=albumalbum_id=863573480386924   '
#   'https://www.facebook.com/exmark/photos/?tab=albums  - '
#   'https://www.facebook.com/exmark/photos/?tab=albumalbum_id=789779197766353   '
#   'https://www.facebook.com/exmark/photos/?tab=albumalbum_id=766452626765677   '
#   'https://www.facebook.com/exmark/photos/?tab=albumalbum_id=735089543235319                         '
#   '!!!      model card  Model card     '
#   'https://www.facebook.com/notes/%E9%A9%9A%E5%98%86%E8%99%9F%E8%97%9D%E8%83%BD/%E9%97%9C%E6%96%BC%E5%AE%A3%E5%82%B3%E7%85%A7%E7%9A%84%E8%AA%AA%E6%98%8E/1319534068124194/   '
#   'https://www.facebook.com/notes/%E9%A9%9A%E5%98%86%E8%99%9F%E8%97%9D%E8%83%BD/%E6%88%90%E7%82%BA%E5%AD%B8%E5%93%A1/1344687022275565/     '
#   'www.facebook.com/exmark    '),
#  (65,
#   '程式設計師',
#   'https://www.518.com.tw/程式設計師-台北市-內湖區-job-1264024.html?kw=&pi=3',
#   1,
#   ' \r'
#   ' 1. PHP Laravel 5  2. (WindowsLinux) 3. TCP/IP 4.        /            '
#   'LinuxTCP/IP       '),
#  (66,
#   '網站維護管理員',
#   'https://www.518.com.tw/網站維護管理員-台中市-北區-job-60259.html?kw=&pi=3',
#   1,
#   ' \r'
#   ' 1. PHP\r'
#   ' 2. \r'
#   ' 3. \r'
#   ' 4. \r'
#   ' 5. \r'
#   ' 6.       /            JavaPHP    1. PHPASPASP .NetJSPJava\r'
#   ' 2. \r'
#   ' 3. \r'
#   ' 4.   2 '),
#  (67,
#   'UI前端工程師',
#   'https://www.518.com.tw/UI前端工程師-台北市-信義區-job-1356034.html?kw=&pi=3',
#   1,
#   ' \r'
#   ' 1.   2.       /      2             HTML / CSS / JavaScript   ( AngularJS / '
#   'React.js / Backbone / Ember.js )   Node.js   RESTful API      Git    Web '
#   'Security  1-2 '),
#  (68,
#   '網拍幫手',
#   'https://www.518.com.tw/網拍幫手-新北市-新莊區-job-1006349.html?kw=&pi=3',
#   1,
#   ' \r   ,     ...  YahooYahooor Facebook..        /                  2 '),
#  (69,
#   '軟韌體設計工程師',
#   'https://www.518.com.tw/軟韌體設計工程師-台南市-安南區-job-1307725.html?kw=&pi=3',
#   1,
#   ' \r 1.MCU 2.PC Based 3.       /      3    :/:/:/:        1 '),
#  (70,
#   'SAS Coder Resource',
#   'http://case.518.com.tw/casepage-detail-124865.html?from=518&a_id=2183',
#   1,
#   None),
#  (71,
#   'PHP/Asp.net 駐點工程師(年)',
#   'http://case.518.com.tw/casepage-detail-124876.html?from=518&a_id=2183',
#   1,
#   None),
#  (72,
#   'Wordpress 網站含討論區架站',
#   'http://case.518.com.tw/casepage-detail-124875.html?from=518&a_id=2183',
#   1,
#   None),
#  (73,
#   '短期約聘計時內勤人員',
#   'https://www.518.com.tw/短期約聘計時內勤人員-新北市-板橋區-job-1285860.html?kw=&pi=4',
#   1,
#   ' \r'
#   ' key in(word) 4~5.4~6. 140        /          :/:/:/::/:/:/: : '
#   '20~50WordExcel      1 '),
#  (74,
#   '外包文書專員',
#   'https://www.518.com.tw/外包文書專員-新北市-板橋區-job-903211.html?kw=&pi=4',
#   1,
#   ' \r'
#   ' ... .(line). e-mail.e-mail..         /          :/:/:/::/:/:/: : '
#   'WordExcelOutlookWindows XP      1 '),
#  (75,
#   'PHP程式設計師',
#   'https://www.518.com.tw/PHP程式設計師-台中市-西屯區-job-1190940.html?kw=&pi=4',
#   1,
#   ' \r PHP   jqueryjavascript   csshtml        /                   '),
#  (76,
#   '資安電腦維護人員',
#   'https://www.518.com.tw/資安電腦維護人員-新北市-新店區-job-1328480.html?kw=&pi=4',
#   1,
#   ' \r'
#   '            /      3    :/:/:/::/:/:/::/:/:/: : SmartERPWindows '
#   '7WordExcelOutlookPowerPoint  (ERP)    1 '),
#  (77,
#   'Android開發工程師',
#   'https://www.518.com.tw/Android開發工程師-台北市-南港區-job-919982.html?kw=&pi=4',
#   1,
#   ' \r'
#   ' 1.(UX)Androidapp 2.Androidjava 3.AR 4. 5. 1-2app       /      1            '
#   '2-3 '),
#  (78,
#   '專案助理, 專案特助',
#   'https://www.518.com.tw/專案助理,專案特助-台北市-中山區-job-192492.html?kw=&pi=4',
#   1,
#   ' \r'
#   ' 1.  2.  3. ,  3. : 5 (, 9:00~18:00) 4. , ,  ()  5. APP 6.  7.  '
#   '7.              3            1-2 '),
#  (79,
#   'IT及MIS工程師',
#   'https://www.518.com.tw/IT及MIS工程師-台北市-大同區-job-1353473.html?kw=&pi=4',
#   1,
#   ' \r 1. ,  2.  3.  4. NAS 5.        /                  1 '),
#  (80,
#   '商業智慧系統管理師',
#   'https://www.518.com.tw/商業智慧系統管理師-桃園市-平鎮區-job-1025907.html?kw=&pi=4',
#   1,
#   ' \r'
#   ' 1.RBig DataBIERP 2. 3.Microsoft Visual Studio.Net2008(VB.Net Web Form) # '
#   '4.Strategy Companion Analyzer  5.Data warehouse  ETL  OLAP BI 6.SQL '
#   '7.Management report  8.  #:       /            WordExcelOutlookLinuxMySQLMS '
#   'SQLSyBase    Windows OSMS SQL Server  R LanguageStrategy Companion '
#   'Analyzer  1 '),
#  (81,
#   '系統工程師',
#   'https://www.518.com.tw/系統工程師-新北市-汐止區-job-1130758.html?kw=&pi=4',
#   1,
#   ' \r  SQL  SERVER       /      4      MQSeriesMySQLMS SQL   MySQL- Core    '),
#  (82,
#   '網頁程式設計師',
#   'https://www.518.com.tw/網頁程式設計師-彰化縣-員林市-job-704309.html?kw=&pi=4',
#   1,
#   ' \r 1.        /            ASPASP.NETAccessMS SQLHTMLCSS    aspasp.net   '),
#  (83,
#   '網路平台管理',
#   'https://www.518.com.tw/網路平台管理-新北市-泰山區-job-794788.html?kw=&pi=4',
#   1,
#   ' \r 1.  2.        /                   '),
#  (84,
#   '巧連智-MIS工程師',
#   'https://www.518.com.tw/巧連智-MIS工程師-台北市-中正區-job-1347785.html?kw=&pi=4',
#   1,
#   ' \r'
#   ' 1. SEVER   2.Client 3. 4. 5. 6.Firewall,Router,Switch 7. 8.       /      '
#   '1      WordPowerPointExcel    1.1 2.UPS 3.PCWindowsVMware 4.MCSACCNA 5.  '
#   '1 '),
#  (85,
#   '網路資訊管理人員',
#   'https://www.518.com.tw/網路資訊管理人員-台北市-中正區-job-1014863.html?kw=&pi=4',
#   1,
#   ' \r 1.  2.        /      2    :/:/:/: :       ()        1 '),
#  (86,
#   '業務推廣',
#   'https://www.518.com.tw/業務推廣-嘉義市-西區-job-1352677.html?kw=&pi=4',
#   1,
#   ' \r 1 2 3 4                   PhotoImpactAdobe PhotoshopPremiere      1 '),
#  (87,
#   '晚夜班 網拍小幫手',
#   'https://www.518.com.tw/晚夜班網拍小幫手-新北市-泰山區-job-1311229.html?kw=&pi=4',
#   1,
#   ' \r 1. 2.  3.   excel          /                   '),
#  (88,
#   '資訊助理工程師',
#   'https://www.518.com.tw/資訊助理工程師-台北市-松山區-job-692075.html?kw=&pi=4',
#   1,
#   ' \r'
#   '   (C#)/PM  (C#)/PM     1.  2.  3.  4.    1.  2.  3.  4.                    '
#   '50~75       '),
#  (89,
#   'php開發工程師',
#   'https://www.518.com.tw/php開發工程師-高雄市-前鎮區-job-1342325.html?kw=&pi=4',
#   1,
#   ' \r'
#   ' 1. 1php 2. jQuery 3. HTML(javascript           /css) 4. MS SQL/MySQL 5. '
#   'Windows Server,IIS,MS SQL, MySQL 6.  7. API         /      2            '
#   '1-2 '),
#  (90,
#   'unity工程師',
#   'https://www.518.com.tw/unity工程師-高雄市-前鎮區-job-1344470.html?kw=&pi=4',
#   1,
#   ' \r'
#   ' Unity 3DC#, Script 1. 1 2. iOS/Android App  3. () 4. AR/VR 5.        '
#   '/            C++Java ScriptUnity 3D      1-2 '),
#  (91,
#   '網路系統工程師',
#   'https://www.518.com.tw/網路系統工程師-高雄市-三民區-job-1299735.html?kw=&pi=4',
#   1,
#   ' \r 1.\t 2.\t 3.\t 4.\t 5.\t 6.\t 7.\t       /                   '),
#  (92,
#   'IT人員/硬體工程師',
#   'https://www.518.com.tw/IT人員硬體工程師-台中市-北區-job-1350558.html?kw=&pi=4',
#   1,
#   ' \r'
#   ' 1.  2.  3.  4.  5.  6.  7.wordpress       /                Office   EQ  '
#   '1 '),
#  (93,
#   '結帳系統與連線機器控制',
#   'http://case.518.com.tw/casepage-detail-124872.html?from=518&a_id=2183',
#   1,
#   None),
#  (94,
#   '尋找工程師',
#   'http://case.518.com.tw/casepage-detail-124870.html?from=518&a_id=2183',
#   1,
#   None),
#  (95,
#   '火車爬蟲編寫規則抓取資料',
#   'http://case.518.com.tw/casepage-detail-124858.html?from=518&a_id=2183',
#   1,
#   None),
#  (96,
#   'SEO網站企劃專員',
#   'https://www.518.com.tw/SEO網站企劃專員-台中市-北區-job-1350565.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' 1.   2.   3.   4.   5.  SEO   6.   7. HTML  CSS  8.SEO  9.Google360  10.on '
#   'pageoff page  11.GoogleBing       /                HTMLCSS   EQ  1 '),
#  (97,
#   'QA(資深)系統工程師',
#   'https://www.518.com.tw/QA(資深)系統工程師-桃園市-中壢區-job-1108014.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' 1.Notesweb development and maintenance. 2.New project '
#   'implementation.                       1.1 2.1+year experience of '
#   'ASP.net(c#) or Lotus Notes related. 3.1+year experience of Database (SQL '
#   'Server or Oracle).  1 '),
#  (98,
#   'asp程式設計師',
#   'https://www.518.com.tw/asp程式設計師-新北市-三重區-job-1307349.html?kw=&pi=5',
#   1,
#   ' \r'
#   '  1. 2.   1.2 2.WINDOWS SERVER 3.ASPVB SCRIPTMS SQL SERVER MYSQL 4. '
#   '5.       /                  1 '),
#  (99,
#   '電子商務專員',
#   'https://www.518.com.tw/電子商務專員-新北市-新莊區-job-1347079.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' (8,10:00~20:00,) :,. 1.  2. 3.  4., 5.       /      1    :/:/:/: :       '
#   '5 '),
#  (100,
#   'PHP工程師',
#   'https://www.518.com.tw/PHP工程師-桃園市-中壢區-job-1299274.html?kw=&pi=5',
#   1,
#   ' \r   PHPMYSQL CSSJAVA Scripe         /                  1-2 '),
#  (101,
#   '客服工程師',
#   'https://www.518.com.tw/客服工程師-台北市-內湖區-job-1285493.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' 1. APP -  / 2. PC - / 3. OA - PCOA(MIS Trouble shutting) 4.  - /   (1)/ '
#   '(2)MIS (3) (4)PPTEXCEL       /                  1-2 '),
#  (102,
#   '物聯網 - JAVA工程師',
#   'https://www.518.com.tw/物聯網-JAVA工程師-桃園市-龜山區-job-1296462.html?kw=&pi=5',
#   1,
#   ' \r  JAVA Web Service           /      1    :/:/:/: : Java      1 '),
#  (103,
#   'Internet程式設計師',
#   'https://www.518.com.tw/Internet程式設計師-桃園市-龜山區-job-1079169.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' 1. ASPJSPPHP... 2. Server 3.        /      1      '
#   'AccessMySQLDreamweaverHTMLCSSLinuxUNIXASPPHP       '),
#  (104,
#   '軟體工程師',
#   'https://www.518.com.tw/軟體工程師-台北市-萬華區-job-1260366.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' 1.  2.  3. ASP.netC#MS SQLOracle... 4.        /  4    3      '
#   'ASP.NETC#.NET      1-3 '),
#  (105,
#   '維運工程師',
#   'https://www.518.com.tw/維運工程師-台北市-內湖區-job-1170721.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' *First Tier for issue diagnoses and troubleshooting, provider technical '
#   'support and consultant, quickly resolve customers issues and ensure '
#   'customers operation run smoothly.  * Follow up unresolved case on daily '
#   'bases, and provide excellent service to customers. * Communicate with '
#   'customer via e-Mail and Skype * Prepare all necessary reports on regular '
#   'bases and upon customers request * Communication and coordination ability '
#   'and integrate needs from all department * Able to catch up and adopt the '
#   'fast paste operation. * Proactive, aggressive, responsible, and willing to '
#   'learn new thing, most importantly we want a team player.  * Can follow up '
#   'the SOP, documentation to work effectively. * Quick on the uptake, good at '
#   'communication, ability to resolve problems. * Willing to take 24*7 shift, '
#   'mostly Day and Afternoon shift.       /          :/:/:/:  LinuxWindows '
#   'Server 2012CiscoDNSFirewallFTPHTTPJuniperLANHubs/ RoutersTCP/IP  (function '
#   'test)(Usability test)(Bug tracking)  sshVLANVPNWAN * Enthusiastic in '
#   'Internet / IT and new technology * Familiar with Internet / Network / IT. * '
#   'Familiar with monitoring tools (i.e. PRTG/HostMonitor/ Whats Up) * '
#   'University Graduated with degree in Computer Science, Information '
#   'Technology * English ability in reading and writing when reply e-Mail or '
#   'Skype. * CCNA would be a plus.  At least one year work experience in this '
#   'field.  1-3 '),
#  (106,
#   'Operation Specialist',
#   'https://www.518.com.tw/OperationSpecialist-台北市-內湖區-job-1235132.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' *4-5 year experience in IT Support in a professional environment *Strong '
#   'experience in providing 1st/2nd tier IT support *Experience driving support '
#   'ticket management and tracking *Strong ability to manage multiple projects '
#   'and tasks with a team or independently efficiently and effectively *Great '
#   'time management skills and ability to prioritize workload *Great '
#   'troubleshooting skills and understanding of IT problem-solving techniques '
#   'and methodology *Diagnosis incudes checking monitoring system, basic '
#   'network and application health assessment, operation system level checks, '
#   'network  system log files, and configuration. *Issue triage includes '
#   'reproducing errors (Product use, data issue, connectivity issue), '
#   'collecting detailed network  system information and, necessary, escalating '
#   'to database or application development staff. *Ability to participate in an '
#   'on-call rotation that includes after hours support *Shift Rotation 24 x '
#   '7       /      4          *College or above in the field of computer '
#   'science, information sciences *Demonstrated the ability to work in highly '
#   'dynamic and high pressure environments *Demonstrated aptitude for problem '
#   'solving  analytical thinking *Networking : Router, Switches *Web '
#   'Technologies : Apache Web Services, Load Balancing and IIS *Virtualization '
#   'Technologies : VMWare, Citrix *Excellent customer management and service '
#   'skills *Ability to communicate effectively, verbally and in writing '
#   '*Self-sufficient, self-managed, self, motivated, must be effective working '
#   'independently, attention to detail. *Develop and maintain job schedules '
#   'based on user documentation. *Assure that documentation and standards are '
#   'maintained.   '),
#  (107,
#   'MIS Specialist',
#   'https://www.518.com.tw/MISSpecialist-台北市-內湖區-job-1170755.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' 1. Maintain/Deploy AD/DNS/VPN/FTP/WEB/E-Mail/Firewall/VMWare/SQL(running '
#   'base) system been implemented by MS-Windows(80%), FreeBSD and/or '
#   'Linux(20%). 2. Co-operate with group staff across Asia on system '
#   'developing, QA platform managing, world-wide routing and IT infrastructure. '
#   '3. Emergency situation take care. 4. Take care of customer/user support and '
#   'complains. 5. Periodicity backup/upgrade/update operation. 6. Quality '
#   'Assurance on in-house software. 7. Local office hardware and inventory '
#   'support(limited). 8. Other supporting jobs.  Qualification: 1. With '
#   'passion, aggressive and careful on the said jobs. 2. 3+ years hands-on '
#   'experience on Windows servers. 3. Passion on IT technology, love to deploy '
#   'new solutions. 4. Be able to communication in English with oversea staff '
#   'and/or customers. 5. Familiar on routing, firewall, VPN as well as proxy, '
#   'NAT and TCP/IP. 6. Familiar with MS-AD, MS-SQL(non-coding), IIS, Exchange, '
#   'Sharepoint, VMWare and Citrix XenServer.  7. Experience on handling various '
#   'vendor is a plus. 8. Familiar on Linux is a plus. 9. Familiar with '
#   'scripting is a plus.       ,3      3    :/:/:/:  Systems '
#   'AdministrationCitrixMicrosoft ExchangeMicrosoft '
#   'SharePointVmwareCiscoDHCPDNSFirewallFTPHTTPIISiptablesJuniperLANLDAPMPLSHubs/ '
#   'RoutersTCP/IPIPSSAN/NAS   MCSECCNARHCE SecuritySnifferSquidUDPVLANVPNWAN  '
#   '1-3 '),
#  (108,
#   'System Engineer/Specialist',
#   'https://www.518.com.tw/SystemEngineerSpecialist-台北市-內湖區-job-1170751.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' 1. Maintain/Deploy AD/DNS/VPN/FTP/WEB/E-Mail/Firewall/VMWare/SQL(running '
#   'base) system been implemented by MS-Windows, FreeBSD and/or Linux. 2. '
#   'Co-operate with group staff across Asia on system developing, QA platform '
#   'managing, world-wide routing and IT infrastructure. 3. Emergency situation '
#   'take care. 4. Take care of customer/user support and complains. 5. '
#   'Periodicity backup/upgrade/update operation. 6. Quality Assurance on '
#   'in-house software. 7. Local office hardware and inventory support(limited). '
#   '8. Other supporting jobs.       ,3      5    :/:/:/:  CitrixMicrosoft '
#   'ExchangeMicrosoft SharePointVmwareCheckpointDNSFirewallIISLANLDAPLoad '
#   'BalancingTCP/IP    SecuritySnifferVLANVPNWAN Qualification: 1. With '
#   'passion, aggressive and careful on the said jobs. 2. 5+ years hands-on '
#   'experience on Windows servers. 3. Passion on IT technology, love to deploy '
#   'new solutions. 4. Be able to communication in English with oversea staff '
#   'and/or customers. 5. Familiar on routing, firewall, VPN as well as proxy, '
#   'NAT and TCP/IP. 6. Familiar with MS-AD, MS-SQL(non-coding), IIS. 7. '
#   'Experience on handling various vendor is a plus. 8. Familiar with VMWare is '
#   'a plus. 9. Familiar with scripting is a plus. 10. Familiar with '
#   'TFS/Sharepoint(non-coding) is a plus.  1-3 '),
#  (109,
#   'Network Engineer/Specialist',
#   'https://www.518.com.tw/NetworkEngineerSpecialist-台北市-內湖區-job-1170750.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' 1. Maintaining and optimizing existing network infrastructure. 2. '
#   'Provisioning/Implementing/Testing from network service with customer scope. '
#   '3. Proposing technical solutions base on customer requirement. 4. Providing '
#   'technical and SOP training internally. 5. Network monitoring system '
#   'maintaining and management. 6. Generating and maintaining documents in '
#   'network team. 7. ASN and public IP addressing management. 8. TCP/IP and DNS '
#   'maintaining and management. 9. AAA system maintaining and management. 10. '
#   'Networking projects management.       /      5    :/:/:/:  '
#   'CiscoDNSFirewallHTTPJuniperLANLoad BalancingHubs/ RoutersTCP/IPBGP   '
#   'JNCIACCNAJNCIA-JUNOSJNCIA-SSLJNCIS-EJNCIS-ERJNCIS-MJNCIP-EJNCIP-M Technical '
#   'skills: Server Load BalancingBGPOSPFHTTPHTTPSDNSFirewallTCP/IPSTPQoSHigh '
#   'AvailabilitySSLVPNVRRPHSRP802.3ADLACP802.1Q  Technical Licenses: Juniper '
#   'NetworksCCNACCNPJNCIAJNCISJNCIP More PreferJNCSPCCIEJNCIEPMP  Others: '
#   'Self-motivated, independent and proactive Analytical thinking, systematic '
#   'and organized Always strive for high performance A win-win team player '
#   'Self-management and good working interaction  2-3 '),
#  (110,
#   'Operation Manager',
#   'https://www.518.com.tw/OperationManager-台北市-內湖區-job-1170735.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' 1. Efficient and effective of the supervise daily/weekly/monthly operation '
#   'of the Operation Support Department 2. Ensure incident under the grasp and '
#   'control 3. Ensure a high degree of satisfaction with services support task '
#   '4. Maintain excellence customer service and relationship management 5. '
#   'Maintain close cooperation with group various departments 6. Organization '
#   'and management of 7x24 duty shift 7. Definition and Document of the SOP, '
#   'and SOP education training and exercise 8. Coordination with the customer '
#   'for maintenance and troubleshooting 9. Ensure the operation service support '
#   'immediate response strategy 10. Periodic reporting data collection and '
#   'compilation 11. Superior negotiating skills 12. Excellent English '
#   'negotiation and written skills       ,1  9-12    10    :/:/:/::/:/:/:    '
#   '(function test)(Usability test)(Bug tracking)  1. Project management and '
#   'Implementation experience  2. Clear thoughts and incident sensitive '
#   'olfactory  3. A certain degree of SI or IT industry knowledge background is '
#   'a plus  4. A win-win team player  5. Analytical thinking, systematic and '
#   'organized  6. EQ Management and control  7. Self-motivated, independent and '
#   'proactive  1 '),
#  (111,
#   '網拍直播小助手',
#   'https://www.518.com.tw/網拍直播小助手-新北市-新莊區-job-1313373.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' 12:30~20:30 , // ,2,  https://www.facebook.com/yujingShiang/  '
#   'https://www.facebook.com/jenchingd/       /          :/:/:/: : '
#   '50~75       '),
#  (112,
#   '研發部門主管(台中)',
#   'https://www.518.com.tw/研發部門主管(台中)-台中市-南屯區-job-1322266.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' WEBAPP       /  4    2      HTMLCSSjQueryJavaScriptMySQLPHPAJAX    PHP '
#   'FrameworkLavarel   '),
#  (113,
#   'WEB程式設計師(台中)',
#   'https://www.518.com.tw/WEB程式設計師(台中)-台中市-南屯區-job-496268.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' WEB php framework Laravel        /      1      HTMLCSSMySQLJava '
#   'ScriptPHPAJAX      1-3 '),
#  (114,
#   '電腦維護工程師',
#   'https://www.518.com.tw/電腦維護工程師-台北市-中山區-job-1039087.html?kw=&pi=5',
#   1,
#   ' \r'
#   ' 1.  2.  3.  4. MCP , MTA , LPIC       /,1      1    :/:/:/::/:/:/: : '
#   'Windows XPWindows VistaWindows 2003Windows 7Windows 2000UNIXLinux       '),
#  (115,
#   'ERP軟體程式設計師',
#   'https://www.518.com.tw/ERP軟體程式設計師-高雄市-左營區-job-322232.html?kw=&pi=5',
#   1,
#   ' \r'
#   '  javascript    ,jQuery, java ,C# ,HTML   C# APP             '
#   '/                  3 '),
#  (116,
#   '網站爬蟲程式抓取資料   (長期合作)',
#   'http://case.518.com.tw/casepage-detail-124820.html?from=518&a_id=2183',
#   1,
#   None),
#  (117,
#   'FB廣告資訊數據收集',
#   'http://case.518.com.tw/casepage-detail-124817.html?from=518&a_id=2183',
#   1,
#   None),
#  (118,
#   '基於 IMU9250 實作電子羅盤',
#   'http://case.518.com.tw/casepage-detail-124809.html?from=518&a_id=2183',
#   1,
#   None),
#  (119,
#   '資訊助理人員',
#   'https://www.518.com.tw/資訊助理人員-高雄市-左營區-job-602256.html?kw=&pi=6',
#   1,
#   ' \r          /                  2 '),
#  (120,
#   '會計出納',
#   'https://www.518.com.tw/會計出納-高雄市-左營區-job-1269408.html?kw=&pi=6',
#   1,
#   ' \r          /                  1 '),
#  (121,
#   '行政助理',
#   'https://www.518.com.tw/行政助理-台中市-北屯區-job-1342376.html?kw=&pi=6',
#   1,
#   ' \r 1. 2.(ERP)       /      1      ExcelWordPowerPoint       '),
#  (122,
#   '韌體設計工程師',
#   'https://www.518.com.tw/韌體設計工程師-台南市-後壁區-job-525382.html?kw=&pi=6',
#   1,
#   ' \r'
#   ' 1.        /            WordExcel3D MaxAutoCADSolidWorksCorel '
#   'DrawC/C++PC      2 '),
#  (123,
#   'MIS助理工程師',
#   'https://www.518.com.tw/MIS助理工程師-台北市-南港區-job-1328982.html?kw=&pi=6',
#   1,
#   ' \r'
#   ' MIS,,    1. ()  2.   3.   4.   5.   6.        /          :/:/:/:        '
#   '1 '),
#  (124,
#   '約聘工程師助理-二個月',
#   'https://www.518.com.tw/約聘工程師助理-二個月-台北市-南港區-job-1328573.html?kw=&pi=6',
#   1,
#   ' \r MIS,,  1. () 2.   3.         /            WordPowerPoint      5 '),
#  (125,
#   '包裝員/作業員',
#   'https://www.518.com.tw/包裝員作業員-台南市-後壁區-job-150956.html?kw=&pi=6',
#   1,
#   ' \r        /                  1-2 '),
#  (126,
#   '網站維護管理員',
#   'https://www.518.com.tw/網站維護管理員-台北市-內湖區-job-1222644.html?kw=&pi=6',
#   1,
#   ' \r        /          :/:/:/:        1 '),
#  (127,
#   '程式設計助理工程師',
#   'https://www.518.com.tw/程式設計助理工程師-台中市-南區-job-1340901.html?kw=&pi=6',
#   1,
#   ' \r'
#   ' 1.(asp.net mvc in c#,javascript                                ) 2.  : 1. '
#   '2.,, 3.       /                   '),
#  (128,
#   '網頁設計師',
#   'https://www.518.com.tw/網頁設計師-高雄市-仁武區-job-1293901.html?kw=&pi=6',
#   1,
#   ' \r'
#   ' 1. 2. 3.PHP-MySQL 4.       /          :/:/:/::/:/:/: : '
#   'DreamweaverHTMLCSSXML Web services       1-2 '),
#  (129,
#   '購物網站管理人員',
#   'https://www.518.com.tw/購物網站管理人員-高雄市-仁武區-job-986664.html?kw=&pi=6',
#   1,
#   ' \r'
#   ' 1.... 2. 3. 4.PchomeMOMO...... 5. 8       /      2      '
#   'ExcelPowerPointAdobe PhotoshopHTMLCorel Draw        (htmlCSS)   1 '),
#  (130,
#   '[KSD]電腦維修工讀生/週休二日/晚上不會加班(路竹)',
#   'https://www.518.com.tw/[KSD]電腦維修工讀生週休二日晚上不會加班(路竹)-高雄市-路竹區-job-1333813.html?kw=&pi=6',
#   1,
#   ' \r'
#   ' 1. 2.:8:00~12:00   13:00~17:00() *MAILdoris.huang@champions.com.tw, *: '
#   '*        /                  1 '),
#  (131,
#   '世大運 資通處設備組 行政專員',
#   'https://www.518.com.tw/世大運資通處設備組行政專員-台北市-松山區-job-1348119.html?kw=&pi=6',
#   1,
#   ' \r'
#   '     1.  2.  3.  4.    1.  2.  3.  4.    upower.tp2@gmail.com     1.() 2. '
#   '3. (...) 4.       /                1.  2.  3.  4.   1 '),
#  (132,
#   '世大運 資通處規劃組 行政專員',
#   'https://www.518.com.tw/世大運資通處規劃組行政專員-台北市-松山區-job-1348112.html?kw=&pi=6',
#   1,
#   ' \r'
#   '     1.  2.  3.  4.    1.  2.  3.  4.    upower.tp2@gmail.com     1.() 2. '
#   '3. (...) 4.       /                1.  2.  3.  4.   1 '),
#  (133,
#   '(中科)自動化機械設備-軟體設計課長-(全職代徵)',
#   'https://www.518.com.tw/(中科)自動化機械設備-軟體設計課長-(全職代徵)-台中市-后里區-job-1342785.html?kw=&pi=6',
#   1,
#   ' \r'
#   ' 1. 2.(PC Base) 3.I/O 4. 5.Visual C#Deiphi 6. 7. 8. 9. 10. 11.       ,3  '
#   '9-12    1    :/:/:/:  Visual C#WinFormVisual Studio .net      3-5 '),
#  (134,
#   '(中科)自動化機械設備-軟體設計工程師(全職代徵)',
#   'https://www.518.com.tw/(中科)自動化機械設備-軟體設計工程師(全職代徵)-台中市-后里區-job-1342732.html?kw=&pi=6',
#   1,
#   ' \r'
#   ' 1. 2.(PC Base) 3.I/O 4. 5.Visual C#Deiphi 6. 7.       ,3  9-12    1    '
#   ':/:/:/:  Visual C#WinFormVisual Studio .net      3-5 '),
#  (135,
#   '[KSD]路竹電腦維修工讀生/週休二日',
#   'https://www.518.com.tw/[KSD]路竹電腦維修工讀生週休二日-高雄市-路竹區-job-991885.html?kw=&pi=6',
#   1,
#   ' \r'
#   ' 1. 2.:8:00~12:00   13:00~17:00() *, *: '
#   '*MAILdoris.huang@champions.com.tw,        /                  1 '),
#  (136,
#   '[KSD]路竹長期資管工讀生/週休二日(對電腦有興趣者)',
#   'https://www.518.com.tw/[KSD]路竹長期資管工讀生週休二日(對電腦有興趣者)-高雄市-路竹區-job-662156.html?kw=&pi=6',
#   1,
#   ' \r'
#   ' 1. 2.:8:00~12:00   13:00~17:00() *MAILdoris.huang@champions.com.tw, '
#   '*:        /                  1 '),
#  (137,
#   '[KSD]電腦維修工讀生/週休二日/(路竹)',
#   'https://www.518.com.tw/[KSD]電腦維修工讀生週休二日(路竹)-高雄市-路竹區-job-1231290.html?kw=&pi=6',
#   1,
#   ' \r'
#   ' 1. 2.:8:00~12:00   13:00~17:00() *MAILdoris.huang@champions.com.tw, *: '
#   '*        /                  1 '),
#  (138,
#   '公家機關-資訊人員',
#   'https://www.518.com.tw/公家機關-資訊人員-新北市-新莊區-job-1116828.html?kw=&pi=6',
#   1,
#   ' \r'
#   ' ()  ()  ()         ()         ()         ()         ()   ()    ()       '
#   '/      3            1 '),
#  (139,
#   'facebook管理軟體',
#   'http://case.518.com.tw/casepage-detail-124806.html?from=518&a_id=2183',
#   1,
#   None),
#  (140,
#   'multicharts策略開發',
#   'http://case.518.com.tw/casepage-detail-124798.html?from=518&a_id=2183',
#   1,
#   None),
#  (141,
#   '反編譯語言',
#   'http://case.518.com.tw/casepage-detail-124782.html?from=518&a_id=2183',
#   1,
#   None),
#  (142,
#   '美編 懂網路',
#   'https://www.518.com.tw/美編懂網路-台北市-士林區-job-947355.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' 1. ) 2.  3.       PM16:00~AM01:00        PM18:00~23:00  20:00~01:00(5~6) '
#   '0952254523        /      5    :/:/:/:  ExcelWordPowerPointOutlookInternet '
#   'ExplorerIllustratorCorel DrawAdobe Photoshop50~75      1 '),
#  (143,
#   '(總公司)資訊中心/系統分析師',
#   'https://www.518.com.tw/(總公司)資訊中心系統分析師-台北市-大安區-job-1202761.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' 1. TIPTOP 2. POS 3. BI 4.  5.  6.  7.  8.ERP 9.ERP 10.SQL 11.ERP 12. '
#   '13.       /      5          TIPTOP   1 '),
#  (144,
#   '資深Front-end前端工程師(研一)',
#   'https://www.518.com.tw/資深Front-end前端工程師(研一)-台北市-內湖區-job-1349329.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' [] 1.(jQueryAJAXjsonASP.NETMVC) 2.HTML5CSS3 3. 4. 5.       /          '
#   ':/:/:/::/:/:/:  AJAXASP.NETHTMLJavaScriptXMLjQuery    '
#   '1.Javascriptex:JQuery. AngularJS 2.Ajaxstring/xml/json 3.3  1-2 '),
#  (145,
#   '專案執行專員',
#   'https://www.518.com.tw/專案執行專員-台北市-內湖區-job-1349315.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' 1.\t 2.\t 3.\t 4.\t       /      2    :/:/:/::/:/:/:  '
#   'WordPowerPointExcelOutlookInternet Explorer    Mobile/APP// internet2  2 '),
#  (146,
#   '高級/資深資料庫程式設計師(研發二部)',
#   'https://www.518.com.tw/高級資深資料庫程式設計師(研發二部)-台北市-內湖區-job-1329321.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' :  1. (//) 2.  3. SQL  : 1.SQL-92, MS_SQL 2.MS_SQL// 3.       /      3    '
#   ':/:/:/::/:/:/:  MS SQLRDBMS      - MS SQLRDBMS    -   -   : 1.SQL-92, '
#   'MS_SQL 2.MS_SQL// 3.   '),
#  (147,
#   '資料庫程式設計師(研一)',
#   'https://www.518.com.tw/資料庫程式設計師(研一)-台北市-內湖區-job-1329301.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' 1. (//) 2.  3. SQL : 1.SQL-92, MS_SQL 2.MS_SQL// 3.       /      3    '
#   ':/:/:/::/:/:/:  MS SQLRDBMS    :  1.SQL Server 2012Reporting Service 2. 3. '
#   '4.Mongo DB 5.   '),
#  (148,
#   'KEY IN工讀生',
#   'https://www.518.com.tw/KEYIN工讀生-桃園市-桃園區-job-1340728.html?kw=&pi=7',
#   1,
#   ' \r ~KEY IN        /          :/:/:/: :     ~  2 '),
#  (149,
#   'RWD網頁設計切版',
#   'https://www.518.com.tw/RWD網頁設計切版-台中市-北區-job-318456.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' 1. RWD 2. JavaScript,jQuery, 3. RWD 4.        /      2      '
#   'HTMLjQueryCSSJavaScript    1  2 3 4  1 '),
#  (150,
#   '知名電信-國際NOC機房維運助理',
#   'https://www.518.com.tw/知名電信-國際NOC機房維運助理-台北市-中正區-job-1350964.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' 1.(WordExcelPowerPoint) 2. 3. 4. 5. 6.500       /          :/:/:/:      1. '
#   '3-6 2.  3. 550 4.    '),
#  (151,
#   '知名電信-程式助理工程師',
#   'https://www.518.com.tw/知名電信-程式助理工程師-台北市-中正區-job-1352279.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' 1. 2.  3. 4. 5.       /            ASPC#C#.NETPL/SQLVBA    MCSDMCSD for '
#   '.NET   1 '),
#  (152,
#   '網管工程師 (台北)',
#   'https://www.518.com.tw/網管工程師(台北)-台北市-松山區-job-1349540.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' 1.  2.  3.  4.  5.  6.  L2, L3  7.  SQL,Server, Linux  1.               2. '
#   ':  : ,        ,      4      Windows 95Windows Server 2008Windows Server '
#   '2012WordExcelOutlook      1 '),
#  (153,
#   '網拍美編銷售人員/網拍上架/美工設計',
#   'https://www.518.com.tw/網拍美編銷售人員網拍上架美工設計-台南市-仁德區-job-1189920.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' 1) / 2)  3)  4)        /            Adobe PhotoshopIllustrator      1-3 '),
#  (154,
#   'PHP網站程式設計師',
#   'https://www.518.com.tw/PHP網站程式設計師-彰化縣-彰化市-job-573195.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' ERPBI ....          /      1      PHPJava '
#   'ScriptLinuxFreeBSDHTMLCSSFlashAJAX      1 '),
#  (155,
#   'MIS程式設計師',
#   'https://www.518.com.tw/MIS程式設計師-彰化縣-彰化市-job-1272817.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' *      - ERPACCBI      -       - *      -      - '
#   '(ApacheNginxPHPMySQL)      -       /      2      '
#   'LinuxPHPAJAXJavaScriptCSSjQueryHTMLMySQLMS SQLHTTPCVSGhost  (ERP)  '
#   '-PHPPHPAjaxMySQLMSSQL - Laravel  -Linux  1 '),
#  (156,
#   '網拍資訊助理',
#   'https://www.518.com.tw/網拍資訊助理-彰化縣-彰化市-job-1140339.html?kw=&pi=7',
#   1,
#   ' \r'
#   '                   1      ExcelPowerPointWord50~75HTML     PCHOMEMOMO  1 '),
#  (157,
#   '現場工程師',
#   'https://www.518.com.tw/現場工程師-彰化縣-員林市-job-1276232.html?kw=&pi=7',
#   1,
#   ' \r io       /  5-8    1      WordExcelGhostPowerPoint      2 '),
#  (158,
#   '多媒體網站設計師',
#   'https://www.518.com.tw/多媒體網站設計師-台北市-信義區-job-204147.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' 1. ()\r'
#   ' 2. \r'
#   ' 3. /\r'
#   ' 5.                        1. /()(\r'
#   ' 2. 1\r'
#   ' 3. \r'
#   ' 4. \r'
#   ' 5. \r'
#   ' (1).\r'
#   ' (2).  1-2 '),
#  (159,
#   '資料庫工程師',
#   'https://www.518.com.tw/資料庫工程師-台北市-信義區-job-203102.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' 1.(MySQLSQL ServerDB 2Oracle Sybase )\r'
#   ' 2.\r'
#   ' 3.\r'
#   ' 4.trouble shootingtuning\r'
#   ' 5.                       1.\r'
#   ' 2.\r'
#   ' 3.MS SQLOracleSybase\r'
#   ' 4.\r'
#   ' 5..\r'
#   ' 6.  1-2 '),
#  (160,
#   '資訊服務人員',
#   'https://www.518.com.tw/資訊服務人員-台北市-信義區-job-210566.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' 1.\r'
#   ' 2.\r'
#   ' 3.survey\r'
#   ' 4.\r'
#   ' 5.\r'
#   ' 6.webapp\r'
#   ' 7.                       1.\r'
#   ' 2.App\r'
#   ' 3.IT\r'
#   ' 4.\r'
#   ' 5.  1-3 '),
#  (161,
#   '程式設計師',
#   'https://www.518.com.tw/程式設計師-台北市-信義區-job-203111.html?kw=&pi=7',
#   1,
#   ' \r'
#   ' 11 \r'
#   ' 2VB.JAVA.Visual Studio.JSP.PHP.ASP.COBOL.XML.C/C++ \r'
#   ' 3Window server.UNIX.LINUX \r'
#   ' 4Access.Oracle.DB2.My SQL.MS SQL                       1.Web\r'
#   ' 2.\r'
#   ' 3.  1-2 '),
#  (162,
#   'Line防翻群機器人',
#   'http://case.518.com.tw/casepage-detail-124781.html?from=518&a_id=2183',
#   1,
#   None),
#  (163,
#   'Mac USB driver 移植',
#   'http://case.518.com.tw/casepage-detail-124778.html?from=518&a_id=2183',
#   1,
#   None),
#  (164,
#   '微信Wechat開發',
#   'http://case.518.com.tw/casepage-detail-124777.html?from=518&a_id=2183',
#   1,
#   None),
#  (165,
#   'Account Manager',
#   'https://www.518.com.tw/AccountManager-台北市-信義區-job-528018.html?kw=&pi=8',
#   1,
#   ' \r'
#   ' 1.IT 2. 3.IT 4.support 5.know-how                       1. 2. 3.ITIT 4..  '
#   '1-2 '),
#  (166,
#   '資訊系統工程師',
#   'https://www.518.com.tw/資訊系統工程師-台北市-信義區-job-202282.html?kw=&pi=8',
#   1,
#   ' \r'
#   ' 1.\r'
#   ' 2.\r'
#   ' 3.                       1.2\r'
#   ' 2.1.SQL Server 2000 2.Windows 2000 Server Windows 2003 Server Windows XP  '
#   'Server 3. Windows 98  Windows XP  Vista4.MS Office5.6.  1-3 '),
#  (167,
#   'General Sales Specialist',
#   'https://www.518.com.tw/GeneralSalesSpecialist-台北市-信義區-job-657438.html?kw=&pi=8',
#   1,
#   ' \r 1.\r 2.//\r 3.\r 4.                       1.\r 2.\r 3.  1-3 '),
#  (168,
#   'Node.js 工程師-台北總處',
#   'https://www.518.com.tw/Node.js工程師-台北總處-台北市-中山區-job-1327702.html?kw=&pi=8',
#   1,
#   ' \r'
#   '   1.  JavascriptES6ES7  2.  NodeJS , MongoDB  NoSQL Database  3.  Express  '
#   'Web   4.  Git Bug issue tracking  5.   6.   7.   8.     : APP  :   : KPI   '
#   ':  :         MyGoMyGo  MyGo MyGo.com / MyGoNews.com / MyGo Plus '
#   'APPUBERMyGo.comMyGo Plus APP DNA       /      1           : A. 1~3APP B.  '
#   'NodeJS (ExpressJS) C.  MongoDB (Mongoose) D.Restful API E.Git F. Unit Test '
#   'FrameworkRSpec(ruby)Mocha(Javascript) Ability to Produce Clean/Maintainable '
#   'code  : A. AWS/Heroku/CI B. Strong Code Design / Database Design Skills '
#   'C.React, HTML/CSS D.  (GitHub, Stack Overflow, Blog, YouTube, etc)   '),
#  (169,
#   '響應式網頁前端工程師',
#   'https://www.518.com.tw/響應式網頁前端工程師-台北市-信義區-job-1233906.html?kw=&pi=8',
#   1,
#   ' \r'
#   ' 1. 2.Web 3.APPJavaScript API 4.AJAX 5.    HTML5/ CSS3  AjaxJavaScript  '
#   'JQuery  (Responsive Web Design)       /      1      '
#   'DHTMLHTMLCSSjQueryXHTMLDreamweaverJavaScriptJ2EEMySQLC#.NETASP.NETiOSAndroidC++C#      '
#   '1 '),
#  (170,
#   '機械軟體工程師',
#   'https://www.518.com.tw/機械軟體工程師-台中市-大里區-job-1163095.html?kw=&pi=8',
#   1,
#   ' \r 1.  2.  3. PC       ,1          :/:/:/:  LabVIEWPythonC#      1 '),
#  (171,
#   '小新樂器館-徵Linux系統網路工程師/Server基本維運',
#   'https://www.518.com.tw/小新樂器館-徵Linux系統網路工程師Server基本維運-新北市-蘆洲區-job-1278457.html?kw=&pi=8',
#   1,
#   ' \r'
#   ' - ,  Linux-Server    EthernetFirewallRoutersTCP/IP  switchServer '
#   'XenCenterSMTPDNS  DHCPAWS/     1.  2.  3.  4.  5.  6.       /      2      '
#   'MySQLMS SQLC++Mac/MacintoshIBMTCP/IPLinux      1-2 '),
#  (172,
#   '硬體工程師',
#   'https://www.518.com.tw/硬體工程師-苗栗縣-竹南鎮-job-22243.html?kw=&pi=8',
#   1,
#   ' \r'
#   ' .,,,Layout,.,...          /      2    :/:/:/: : '
#   'CAMSMTPCBAOrCADProtelEMC/EMIDriversAutoCad 2DPhotopiaAutoCad 3D  PCB '
#   'LayoutPCBPCBPCBPCBPCBPCBIC    1 '),
#  (173,
#   '專利工程師',
#   'https://www.518.com.tw/專利工程師-苗栗縣-竹南鎮-job-1174286.html?kw=&pi=8',
#   1,
#   ' \r           /                   '),
#  (174,
#   '軟軔體工程師',
#   'https://www.518.com.tw/軟軔體工程師-苗栗縣-竹南鎮-job-22239.html?kw=&pi=8',
#   1,
#   ' \r'
#   ' 1.. (3C); 2.C;Matlab. Labview.vb.net.java. 2.. 3.IC." IC 4.        '
#   '/          :/:/:/: : MCUBluetoothC/C++Java      1 '),
#  (175,
#   '業務工程師',
# ...
#  (1150,
#   '軟體業務/行銷人員',
#   'https://www.518.com.tw/軟體業務行銷人員-桃園市-八德區-job-1029284.html?kw=&pi=50',
#   1,
#   ' \r'
#   ' 1.  2. , 3.          /          :/:/:/: : PowerPointWordExcelWindows '
#   'XPWindows 7Windows 2003PCHTMLPOS      1 '),
#  (1151,
#   '下單程式修正',
#   'http://case.518.com.tw/casepage-detail-122640.html?from=518&a_id=2183',
#   1,
#   None),
#  (1152,
#   'FPGA接上AD所產生的noise',
#   'http://case.518.com.tw/casepage-detail-122631.html?from=518&a_id=2183',
#   1,
#   None),
#  (1153,
#   'Ecshop串接。綠界金流，超商取件',
#   'http://case.518.com.tw/casepage-detail-122581.html?from=518&a_id=2183',
#   1,
#   None),
#  (1154,
#   '軟體業務/行銷人員',
#   'https://www.518.com.tw/軟體業務行銷人員-桃園市-八德區-job-1029284.html?kw=&pi=51',
#   1,
#   ' \r'
#   ' 1.  2. , 3.          /          :/:/:/: : PowerPointWordExcelWindows '
#   'XPWindows 7Windows 2003PCHTMLPOS      1 '),
#  (1155,
#   '網路應用與管理',
#   'https://www.518.com.tw/網路應用與管理-台中市-北屯區-job-1313288.html?kw=&pi=51',
#   1,
#   ' \r 1. \r 2. \r 3.         /                 '),
#  (1156,
#   '系統工程師',
#   'https://www.518.com.tw/系統工程師-台南市-北區-job-679367.html?kw=&pi=51',
#   1,
#   ' \r'
#   '  \r'
#   '  Exchange  AD \r'
#   '   MCITP        ,      2    :/:/:/::/:/:/:  Windows 2003Windows 7   '
#   'MCITP    '),
#  (1157,
#   '電腦工程師(後端)',
#   'https://www.518.com.tw/電腦工程師(後端)-台中市-南屯區-job-1191073.html?kw=&pi=51',
#   1,
#   ' \r'
#   ' PHP / MVC /Laravel /Lnmen/C# /Git()\r'
#   '        /      1    :/:/:/::/:/:/: :     **  1 '),
#  (1158,
#   '資訊總務人員',
#   'https://www.518.com.tw/資訊總務人員-台北市-南港區-job-181458.html?kw=&pi=51',
#   1,
#   ' \r        ,            Windows XPWord      2 '),
#  (1159,
#   'PHP工程師',
#   'https://www.518.com.tw/PHP工程師-台中市-西屯區-job-823283.html?kw=&pi=51',
#   1,
#   ' \r'
#   ' PHP   jqueryjavascript     csshtml        /      1      MySQLLinuxJava '
#   'Script      1 '),
#  (1160,
#   '軟體工程師',
#   'https://www.518.com.tw/軟體工程師-桃園市-蘆竹區-job-1312935.html?kw=&pi=51',
#   1,
#   ' \r'
#   ' .net / java / SQLC,VB :SQL       ,      2      CJava    '
#   'NET.JAVA,SQL,C,VB,...   '),
#  (1161,
#   '電腦維修工程師 _(全職)',
#   'https://www.518.com.tw/電腦維修工程師_(全職)-台中市-北屯區-job-64055.html?kw=&pi=51',
#   1,
#   ' \r'
#   ' ,,,       /,1          :/:/:/::/:/:/: : PCPCWindows 2000Windows NTWindows '
#   'XPWordPowerPointExcelOutlookWindows 7Windows Vista20~5020~50    \r'
#   ' \r'
#   '  \r'
#   '  .,  1 '),
#  (1162,
#   '105年研發替代役-網站程式設計師',
#   'https://www.518.com.tw/105年研發替代役-網站程式設計師-台北市-中山區-job-1119056.html?kw=&pi=51',
#   1,
#   ' \r'
#   ' 1WEB 2 3WEB 4 5WEB       /          :/:/:/:  PHPRuby    1 2MySqlRails '
#   '3Ruby  4PHPJavaScriptCSS3Html5 5Web  http://www.fashioncookie.com.tw '
#   'http://www.corpo.com.tw  1 '),
#  (1163,
#   'Ruby on Rails(ROR)程式工程師',
#   'https://www.518.com.tw/RubyonRails(ROR)程式工程師-台中市-西區-job-1226581.html?kw=&pi=51',
#   1,
#   ' \r'
#   ' 1 1Ruby on RailsB2B/B2C/C2C/ 2 MySQL Relational Database 3 4 5       '
#   '/      1    :/:/:/::/:/:/: : MySQL       '),
#  (1164,
#   '程式設計工程師',
#   'https://www.518.com.tw/程式設計工程師-台中市-沙鹿區-job-1297995.html?kw=&pi=51',
#   1,
#   ' \r 1. \r 2. ASPJSPPHP...        /                 '),
#  (1165,
#   '兼職-APP程式設計師',
#   'https://www.518.com.tw/兼職-APP程式設計師-台北市-大同區-job-1097207.html?kw=&pi=51',
#   1,
#   ' \r'
#   ' 1.Android/iOS APP 2.Android/iOS APP 3.Android/iOS APP 4.Android/iOS '
#   'APP        /                1.Android/iOS APP 2.Android/iOS APP 3.  1 '),
#  (1166,
#   '機率工程師',
#   'https://www.518.com.tw/機率工程師-台中市-西區-job-562561.html?kw=&pi=51',
#   1,
#   ' \r'
#   ' 1. 2. 3. 4. 5.             3    :/:/:/:  ExcelC/C++    1. Excel  2.C++  '
#   '2 '),
#  (1167,
#   'C++資深軟體工程師',
#   'https://www.518.com.tw/C++資深軟體工程師-台中市-西區-job-883813.html?kw=&pi=51',
#   1,
#   ' \r'
#   ' 1. 2. 3. 4.C/C++ 5.OpenGL, OpenAL 6. 7.Third-Party Libraries 8.(x86 / ARM '
#   'Embedded)       /      3    :/:/:/:  C/C++LinuxVisual C++    1. C/C++ 2.  '
#   '3.  4.  5.   6. () 7.  8.   2 '),
#  (1168,
#   '行動App研發工程師',
#   'https://www.518.com.tw/行動App研發工程師-台北市-松山區-job-965030.html?kw=&pi=51',
#   1,
#   ' \r'
#   ' 1. UnityCocos(Client)(Server) 2.        /      1    :/:/:/:      1. '
#   'Demo   '),
#  (1169,
#   '程式設計師',
#   'https://www.518.com.tw/程式設計師-新北市-樹林區-job-381205.html?kw=&pi=51',
#   1,
#   ' \r 1.        /      1      ASPASP.NETPHPHTMLCSS      1 '),
#  (1170,
#   '技術部-網站程式設計師',
#   'https://www.518.com.tw/技術部-網站程式設計師-高雄市-仁武區-job-1162946.html?kw=&pi=51',
#   1,
#   ' \r 1. 2.       /      1            1 '),
#  (1171,
#   '職缺名：Internet程式設計師(.Net)\n工作內容：ASP.net 程式設計..',
#   'https://www.518.com.tw/Internet程式設計師(.Net)-台中市-北區-job-905564.html?kw=&pi=51',
#   1,
#   ' \r'
#   ' ASP.net        /          :/:/:/:  Visual BasicASP.NETWindows 2000AccessMS '
#   'SQL    1.ASP.NET 2.0SQL ServerVisual Web Developer 2. 3.  1 '),
#  (1172,
#   '職缺名：程式設計師\n工作內容：協助公司各項程式開發工作，能獨立開發具有....',
#   'https://www.518.com.tw/程式設計師-台中市-西區-job-1144867.html?kw=&pi=51',
#   1,
#   ' \r'
#   '  1.  2.  3. PHP+MySQL+jQuery 4.        /            '
#   'AJAXPHPMySQLHTMLJavaScriptjQuery       '),
#  (1173,
#   '職缺名：網站修改及維護人員\n工作內容：主要負責公司網站的維護,需懂Joomla程式修....',
#   'https://www.518.com.tw/網站修改及維護人員-台北市-內湖區-job-212774.html?kw=&pi=51',
#   1,
#   ' \r ,Joomla,!        /            FlashFrontPageDreamweaver      1 '),
#  (1174,
#   '電腦軟體工程師',
#   'https://www.518.com.tw/電腦軟體工程師-苗栗縣-苗栗市-job-836555.html?kw=&pi=52',
#   1,
#   ' \r 1.  \r 2. \r 3.        /                   '),
#  (1175,
#   'iOS軟體工程師',
#   'https://www.518.com.tw/iOS軟體工程師-新竹市-全區-job-851201.html?kw=&pi=52',
#   1,
#   ' \r'
#   ' 1)  (Wi-Drive) 2)  3) iOS 4) AndroidWindow Phone 5) HTMLHTML5       /      '
#   '1    :/:/:/:        1-2 '),
#  (1176,
#   '網站修改及維護人員',
#   'https://www.518.com.tw/網站修改及維護人員-台北市-內湖區-job-212774.html?kw=&pi=52',
#   1,
#   ' \r ,Joomla,!        /            FlashFrontPageDreamweaver      1 '),
#  (1177,
#   'App軟體工程師',
#   'https://www.518.com.tw/App軟體工程師-新北市-五股區-job-929026.html?kw=&pi=52',
#   1,
#   ' \r'
#   ' 1.iOS AppAndroid App\r'
#   ' 2.\r'
#   ' 3.\r'
#   ' 4.\r'
#   ' 5.       /      2    :/:/:/: :     App\r'
#   ' App\r'
#   '   1 '),
#  (1178,
#   '網拍網站客服',
#   'https://www.518.com.tw/網拍網站客服-桃園市-八德區-job-28770.html?kw=&pi=52',
#   1,
#   ' \r'
#   '            3.  ()       /            IllustratorAdobe Photoshop     ()  '
#   '1-2 '),
#  (1179,
#   '應用軟體開發工程師',
#   'https://www.518.com.tw/應用軟體開發工程師-台北市-南港區-job-963800.html?kw=&pi=52',
#   1,
#   ' \r'
#   ' 1)  2)  3)  4)        /          :/:/:/::/:/:/: : LinuxVisioAdobe '
#   'AcrobatWordExcelHTMLXMLASP.NETC#.NETJava  (function test)  (1)  (2)  (3)   '
#   '2-3 '),
#  (1180,
#   '3C配件銷售門市工讀生',
#   'https://www.518.com.tw/3C配件銷售門市工讀生-台中市-西屯區-job-1227718.html?kw=&pi=52',
#   1,
#   ' \r'
#   ' * 3C * 1.   2.  3.  4.     14:30 ~ 17:30 17:30 ~ 23:30 **  120 /   : '
#   '2022       /                  10 '),
#  (1181,
#   'PHP軟體工程師',
#   'https://www.518.com.tw/PHP軟體工程師-新竹市-全區-job-1252294.html?kw=&pi=52',
#   1,
#   ' \r 1. 2. 3.       /           : MS SQLMySQLHTMLCSSjQueryPHP      3 '),
#  (1182,
#   '維護工程師',
#   'https://www.518.com.tw/維護工程師-台南市-北區-job-679375.html?kw=&pi=52',
#   1,
#   ' \r'
#   ' \r'
#   '  \r'
#   '  Windows Server        /      1    :/:/:/::/:/:/:  Windows 2003Windows '
#   '7Windows XP  (IPS)(NIDS)     '),
#  (1183,
#   '軟體工程師',
#   'https://www.518.com.tw/軟體工程師-台北市-南港區-job-659192.html?kw=&pi=52',
#   1,
#   ' \r'
#   ' 1.\tLabVIEW 2.\t 3.\t 4.\t       ,1          :/:/:/:  LabVIEW    1.\t'
#   'LabVIEW 2.\t 3.     Windows  4.\t 5.\t 6.\t 7.\t  1 '),
#  (1184,
#   '軟體工程師',
#   'https://www.518.com.tw/軟體工程師-新竹市-北區-job-397836.html?kw=&pi=52',
#   1,
#   ' \r        /      2      Visual Basic .net      1 '),
#  (1185,
#   'Pcb 檢測治具 軟體工程師',
#   'https://www.518.com.tw/Pcb檢測治具軟體工程師-桃園市-蘆竹區-job-897653.html?kw=&pi=52',
#   1,
#   ' \r Pcb       /                   '),
#  (1186,
#   'PHP資深程式設計師',
#   'https://www.518.com.tw/PHP資深程式設計師-新北市-中和區-job-912313.html?kw=&pi=52',
#   1,
#   ' \r'
#   ' 1.  2.  3. PHPMYSQLApache 4.5       /          :/:/:/::/:/:/:  PHP    '
#   '1.PHP 2.JAVA ScriptJQuery 3.CSS 4.  2 '),
#  (1187,
#   'APP程式設計人員',
#   'https://www.518.com.tw/APP程式設計人員-台北市-全區-job-943354.html?kw=&pi=52',
#   1,
#   ' \r 1. ASPJSPPHP... 2. Server 3.         /                   '),
#  (1188,
#   '網拍商品陳列人員',
#   'https://www.518.com.tw/網拍商品陳列人員-台北市-北投區-job-1152075.html?kw=&pi=52',
#   1,
#   ' \r        /            WordExcelInternet Explorer       '),
#  (1189,
#   '工程師',
#   'https://www.518.com.tw/工程師-桃園市-平鎮區-job-953319.html?kw=&pi=52',
#   1,
#   ' \r'
#   ' 1.\t 2.\tVisual Studio.NET 3.\tMS-SQL Server/ Oracle Database 4.\t 5.\t '
#   '6.\t 7.\t/ 8.\t  1.\tVisaul Studio .NET C#WinForm and WebForm / ASP.Net 2.\t'
#   'Windows CE 7.0 PDA Mobile Device 3.\tMS-SQL Server/ Oracle       '
#   '/                  1-2 '),
#  (1190,
#   '(薪優).Net Developer',
#   'https://www.518.com.tw/(薪優).NetDeveloper-台北市-全區-job-1123380.html?kw=&pi=52',
#   1,
#   ' \r'
#   ' 1.ASP.Net 5  2.JQueryJavaScriptAJAX 3.MS SQL 2008 R2 4.Team Work 5. '
#   '6.       ,                  1-3 '),
#  (1191,
#   '職缺名：Internet程式設計師\n工作內容：1. 從事PHP...等相關網路程式設計語言撰寫....',
#   'https://www.518.com.tw/Internet程式設計師-台北市-士林區-job-996127.html?kw=&pi=52',
#   1,
#   ' \r'
#   ' 1. PHP... 2.  3. (:)       /      2      PHPJava '
#   'ScriptXMLLinuxMySQLHTMLCSSFrontPageIllustratorAdobe '
#   'PhotoshopDHTMLDreamweaverAJAX      1 '),
#  (1192,
#   '職缺名：php程式設計師\n工作內容：1:幫忙建置公司網站程式之修改新增…等，隨....',
#   'https://www.518.com.tw/php程式設計師-新北市-全區-job-831723.html?kw=&pi=52',
#   1,
#   ' \r'
#   ' 1:\r'
#   ' 2:\r'
#   '  \r'
#   '  \r'
#   ' 3:\r'
#   '          /          :/:/:/: : ASPMySQLWindows 7Windows '
#   'XPNovellHTMLCSSASP.NETPHP       '),
#  (1193,
#   '職缺名：網頁設計人員\n工作內容：1. 網站或主機等功能操作或資料校正等工作....',
#   'https://www.518.com.tw/網頁設計人員-嘉義縣-民雄鄉-job-958247.html?kw=&pi=52',
#   1,
#   ' \r'
#   ' 1.  2.  3.         /            WordPowerPointInternet ExplorerAdobe '
#   'AcrobatOutlookExcelCorel DrawIllustratorHTMLFlashWindows 7Windows XP      '
#   '1 '),
#  (1194,
#   '網拍小幫手',
#   'https://www.518.com.tw/網拍小幫手-桃園市-八德區-job-263714.html?kw=&pi=53',
#   1,
#   ' \r'
#   '              ()       /            IllustratorAdobe Photoshop     ()  '
#   '1-2 '),
#  (1195,
#   'Lotus Domino 系統工程師',
#   'https://www.518.com.tw/LotusDomino系統工程師-台北市-中正區-job-959702.html?kw=&pi=53',
#   1,
#   ' \r'
#   ' 1. Lotus Domino / 2.        /,      2    :/:/:/::/:/:/:  Lotus Notes      '
#   '1-2 '),
#  (1196,
#   '安卓工程師和ios工程師',
#   'https://www.518.com.tw/安卓工程師和ios工程師-新竹市-北區-job-1075998.html?kw=&pi=53',
#   1,
#   ' \r 1. ios\r 2.        /                  2 '),
#  (1197,
#   '行政 IT 人員',
#   'https://www.518.com.tw/行政IT人員-台北市-信義區-job-921200.html?kw=&pi=53',
#   1,
#   ' \r'
#   ' 1 2 3 4MIS   5       /      1    :/:/:/::/:/:/:  50~7520~50WordExcel    '
#   '1.3D(STL) 2. 3. 4.2D3D 5. 6.   '),
#  (1198,
#   '網拍助手',
#   'https://www.518.com.tw/網拍助手-台北市-松山區-job-908676.html?kw=&pi=53',
#   1,
#   ' \r    AM 09:00 ~ PM 05:00 PM 02:00 ~ PM 10:00       /                  1 '),
#  (1199,
#   '影像處理演算法工程師',
#   'https://www.518.com.tw/影像處理演算法工程師-台北市-內湖區-job-872607.html?kw=&pi=53',
#   1,
#   ' \r'
#   ' ()       /      1    :/:/:/::/:/:/:  C#.NETC/C++    1.\timage '
#   'processingcomputer vision 2.\t 3.\t 4.\tC/C++C# 5.     openCV  1-2 '),
#  (1200,
#   '軟體工程師(手機相機模組)',
#   'https://www.518.com.tw/軟體工程師(手機相機模組)-新竹縣-竹北市-job-946483.html?kw=&pi=53',
#   1,
#   ' \r'
#   ' 1. Device(CMOS sensor, VCM, motor, OIS, ...) driver camera 2.  3.  4. '
#   'Camera module/ 5. Camera module 6. Camera module 3D       '
#   '/                   '),
#  (1201,
#   '軟體設計工程師',
#   'https://www.518.com.tw/軟體設計工程師-台中市-北區-job-856707.html?kw=&pi=53',
#   1,
#   ' \r 1.  2.  3.         /                   '),
#  (1202,
#   '行政助理或資訊助理',
#   'https://www.518.com.tw/行政助理或資訊助理-台中市-西區-job-679485.html?kw=&pi=53',
#   1,
#   ' \r   1., 2., 3.  4.       /          :/:/:/: :        '),
#  (1203,
#   '外勤電腦維修工程師',
#   'https://www.518.com.tw/外勤電腦維修工程師-台北市-萬華區-job-627066.html?kw=&pi=53',
#   1,
#   ' \r 1. /\r 2.        /      1            2 '),
#  (1204,
#   '人機介面設計工程師(新竹)',
#   'https://www.518.com.tw/人機介面設計工程師(新竹)-新竹縣-寶山鄉-job-847158.html?kw=&pi=53',
#   1,
#   ' \r'
#   ' 1. Mobile Device [Cell phone, Pad, Tablet...]2. : - Familiar with HTML5, '
#   'HTML, JavaScript, ActionScript 2.0/3.0 - 3D drawing, Photoshop, '
#   'Illustrator, Flash - Research in Human Interface UI behavior and being '
#   'creativity.       /          :/:/:/:  LinuxC/C++Java    - - C/C++ Java '
#   'Script - Linux- GUI code  1-2 '),
#  (1205,
#   '二度就業~內勤主機板及電源維修工程師',
#   'https://www.518.com.tw/二度就業~內勤主機板及電源維修工程師-新北市-汐止區-job-694449.html?kw=&pi=53',
#   1,
#   ' \r'
#   ' 1. \r'
#   ' 2. \r'
#   ' 3. ,       /      2    :/:/:/::/:/:/: : PCIBMCompaq    ,\r'
#   ' 1. \r'
#   ' 2. \r'
#   ' 3. ,  2 '),
#  (1206,
#   'ios程式設計師',
#   'https://www.518.com.tw/ios程式設計師-高雄市-苓雅區-job-384665.html?kw=&pi=53',
#   1,
#   ' \r'
#   '  ios App  (1) objective-c / (2)GPS (3)PHP C#MVC             3      '
#   'AJAXC#.NETPHPMS SQLObjective-C     EQ Team Work   PHPMSSQLJQueryMVC   '),
#  (1207,
#   '門市助理',
#   'https://www.518.com.tw/門市助理-桃園市-大溪區-job-666930.html?kw=&pi=53',
#   1,
#   ' \r  \r \r \r         /                 !\r ~\r      '),
#  (1208,
#   '網站美編專員',
#   'https://www.518.com.tw/網站美編專員-新北市-泰山區-job-797249.html?kw=&pi=53',
#   1,
#   ' \r'
#   ' 1.,, \r'
#   ' 2. \r'
#   ' 3.         /      3    :/:/:/::/:/:/:  Adobe '
#   'PhotoshopFlashDreamweaverMySQLMS SQL       '),
#  (1209,
#   '電腦維修工程師',
#   'https://www.518.com.tw/電腦維修工程師-台南市-善化區-job-146481.html?kw=&pi=53',
#   1,
#   ' \r ,,\r 6(),() 10:00~21:00, \r ,!       /      1             '),
#  (1210,
#   '網站程式設計師',
#   'https://www.518.com.tw/網站程式設計師-新北市-板橋區-job-1134117.html?kw=&pi=53',
#   1,
#   ' \r'
#   ' 1. 2. 3. 4. 5.Web-based application 6. 7.ASP.NET       /                  '
#   '1 '),
#  (1211,
#   '職缺名：設備操作員\n工作內容：1. 系統(例:網站或主機等)功能操作或資....',
#   'https://www.518.com.tw/設備操作員-台南市-仁德區-job-947341.html?kw=&pi=53',
#   1,
#   ' \r 1. (:)\r 2. \r 3.        /                  1-3 '),
#  (1212,
#   '職缺名：網站設計人員\n工作內容：網站架設，建立..',
#   'https://www.518.com.tw/網站設計人員-台南市-永康區-job-1208606.html?kw=&pi=53',
#   1,
#   ' \r        /                   '),
#  (1213,
#   '職缺名：網站設計工程師\n工作內容：1. 負責軟體的分析、設計、程式撰寫與維護....',
#   'https://www.518.com.tw/網站設計工程師-彰化縣-福興鄉-job-1209027.html?kw=&pi=53',
#   1,
#   ' \r 1.        /                  1 '),
#  (1214,
#   'Android/ iOS APP開發工程師(中國崑山)',
#   'https://www.518.com.tw/AndroidiOSAPP開發工程師(中國崑山)-新北市-五股區-job-1071547.html?kw=&pi=54',
#   1,
#   ' \r'
#   ' 1. Android  iOS APP 2.\tAndroid/iOS APP 3.\tAndroid/iOS APP 4.\t '
#   'PHPJavaScriptHTML5CSS3SQL 5.\tiOSXCodeObjective C 6.\t App  Server  7.\t 8. '
#   'iOS SDKObjective C     (90%)                 : (1)  (2)  '
#   'www.jingtek.com       ,                   '),
#  (1215,
#   '伺服器及網路-駐點維護工程師 (台北)',
#   'https://www.518.com.tw/伺服器及網路-駐點維護工程師(台北)-台北市-內湖區-job-365447.html?kw=&pi=54',
#   1,
#   ' \r'
#   '      Windows NT/2003/2008         /      1    :/:/:/::/:/:/:  '
#   'WordPowerPointExcelOutlookInternet ExplorerVisioGhostHTMLLinuxWindows '
#   '2003Windows 7Windows VistaWindows XPHPPCPCIBMCompaq50~7550~75  (NIDS)(IPS) '
#   'MCITPMCSECCNA   1 '),
#  (1216,
#   '伺服器網路管理及維護工程師(桃園區)',
#   'https://www.518.com.tw/伺服器網路管理及維護工程師(桃園區)-桃園市-全區-job-365452.html?kw=&pi=54',
#   1,
#   ' \r'
#   '      Windows NT/2000/2003/2008   TCP/IP     Microsoft MCP or Cisco '
#   'CCNA        /      1    :/:/:/::/:/:/:  '
#   'WordExcelOutlookPowerPointVisioInternet ExplorerGhostHTMLMS '
#   'SQLMySQLDOSLinuxWindows 98Windows XPWindows VistaWindows 2000Windows '
#   'NTWindows 2003Windows 7HPPCPCCompaqIBM50~7550~75  (NIDS) LPIC Level 1LPIC '
#   'Level 2MCITPMCPMCSAMCSEMCTSRHCERHCTCCNATCAETCSE    '),
#  (1217,
#   '外勤業務人員',
#   'https://www.518.com.tw/外勤業務人員-高雄市-全區-job-701573.html?kw=&pi=54',
#   1,
#   ' \r 1.  \r 2.        ,                  1 '),
#  (1218,
#   '職缺名：網頁開發工程師\n工作內容：1. 使用HTML5.0進行網頁開發，熟悉JavaSc....',
#   'https://www.518.com.tw/網頁開發工程師-宜蘭縣-宜蘭市-job-1089894.html?kw=&pi=54',
#   1,
#   ' \r'
#   ' 1. HTML5.0JavaScriptHTML5CSS3 2. ASP/PHP/JSP 3. Shell Script/Perl/Python '
#   '4. MySQLDB 5. Client-Server        /      2      WordPowerPointExcelAdobe '
#   'AcrobatLinuxUNIXASPJavaJSPJava ScriptPHPDHTMLHTMLCSSMySQL      1 '),
#  (1219,
#   '職缺名：網路助理工程師\n工作內容：1.具電腦機房維護一年以上經驗者。2.具網路....',
#   'https://www.518.com.tw/網路助理工程師-台北市-信義區-job-883357.html?kw=&pi=54',
#   1,
#   ' \r'
#   ' 1.2.3.PC 4.ERP5.6.7.8.       /          :/:/:/:  DOSLinuxWindows '
#   '2000Windows 98Windows NTC/C++JavaVisual C++Java ScriptVB '
#   'ScriptWordOutlookExcelFrontPageHTMLMS SQLMySQLDbase   MCSEMCSE+ICCNA SuSE '
#   'Linux, ApacheCCNA, MSCE  1 '),
#  (1220,
#   '職缺名：電子工程師(軟體)\n工作內容：單晶片組合語言程式設計、防盜控制系統設計....',
#   'https://www.518.com.tw/電子工程師(軟體)-台北市-信義區-job-6991.html?kw=&pi=54',
#   1,
#   ' \r'
#   '        /          :/:/:/:  C/C++Visual C++WordOutlookExcel    1. 2.   1 ')]

# %% [markdown]
# # 加入單筆

# %%
jid = 1

# %%
with sqlite3.connect('job.sqlite') as conn:
    c = conn.cursor()
#     c.execute('select * from job518')
#     print(c.fetchone())
    updStrting = 'update job518 set info =:info where jobID =:jobID'
    c.execute(updStrting, {'info' : new_info, 'jobID' : jid})

# %%
with sqlite3.connect('job.sqlite') as conn:
    c = conn.cursor()
    c.execute('select * from job518')
    print(c.fetchone())
# Out:
# (1, 'Android程式設計師', 'https://www.518.com.tw/Android程式設計師-新北市-三重區-job-886709.html?kw=&pi=1', 1, ' \r AndroidIOSline3Dapp080sipIVRapp  :1. Java, C++ 2. iOSAndroid 3DApp3. 3D4.  Unity 5. Socket Programming, TCP/IP        /      2          :1. Java, C++ 2. iOSAndroid 3DApp3. 3D4.  Unity 5. Socket Programming, TCP/IP   2 ')
